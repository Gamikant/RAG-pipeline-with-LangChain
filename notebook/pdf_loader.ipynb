# %% [markdown]
# ### 1. RAG pipeline - Data Ingestion to Vector DB Pipeline

# %%
import os
from langchain_community.document_loaders import PyPDFLoader, PyMuPDFLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter
from pathlib import Path

# %%
def process_all_pdfs(pdf_directory):
    """Process all PDF files in a directory"""
    all_documents = []
    pdf_dir = Path(pdf_directory)

    # Find all PDF files recursively
    pdf_files = list(pdf_dir.glob("**/*.pdf"))

    print(f"Found {len(pdf_files)} PDF files to process")

    for pdf_file in pdf_files:
        print(f"\n Processing: {pdf_file.name}")
        try:
            loader = PyPDFLoader(str(pdf_file))
            documents = loader.load()

            # Add source information to metadata
            for doc in documents:
                doc.metadata["source file"] = pdf_file.name
                doc.metadata["file_type"] = 'pdf'
            
            all_documents.extend(documents)
            print(f"Loaded {len(documents)} pages")
        except Exception as e:
            print(f"Error: {e}")

    print(f"\nTotal documents loaded: {len(all_documents)}")
    return all_documents


# Process all PDFs 
all_pdf_documents = process_all_pdfs("../data")
# Out:
# Found 5 PDF files to process
#
#  Processing: AI researcher.pdf
# Ignoring wrong pointing object 12 0 (offset 0)
# Ignoring wrong pointing object 13 0 (offset 0)
# Loaded 2 pages
#
#  Processing: apple_jd.pdf
# Loaded 1 pages
#
#  Processing: Applied Data Scientist.pdf
# Loaded 2 pages
#
#  Processing: Data Engineer.pdf
# Loaded 2 pages
#
#  Processing: DNN Developer.pdf
# Loaded 2 pages
#
# Total documents loaded: 9

# %%
all_pdf_documents
# Out:
# [Document(metadata={'producer': 'Microsoft: Print To PDF', 'creator': 'PyPDF', 'creationdate': '2025-09-19T19:17:00+09:00', 'author': 'AtoJ-Ruchira', 'moddate': '2025-09-19T19:17:00+09:00', 'title': 'IITçŽ»é„²çﬂ¨Job Description(2025-2026)0903æ‘’å⁄º.xlsx', 'source': '..\\data\\pdf\\AI researcher.pdf', 'total_pages': 2, 'page': 0, 'page_label': '1', 'source file': 'AI researcher.pdf', 'file_type': 'pdf'}, page_content='Honda Motor Co., \nLtd. AI Research Engineer\nHonda is a total mobility company dedicated to delivering the "joy of free movement." We innovate in various fields, including motorcycles, automobiles, power products, aircraft and aircraft \nengines, and robotics. Honda operates in markets across about 200 countries worldwide, continuously creating next-generation mobility solutions and products that improve people’s lives by \ncombining our technology and expertise.\nAt Honda, everyone, regardless of nationality, gender, educational background, or experience, can freely express their ideas. Since our founding, we have maintained the ambition of asking, "What \ncan we do for the world and for people?"\nWe believe that having dreams and staying passionate about making them a reality is the reason Honda exists. "It\'s not about what happens; it\'s about what you do." You are the ones who will shape \nthe future of the world. As you move forward in life, we hope you will be the main character in the moments when the world changes.\nIf you have a desire to achieve something, to create something, or to make your dreams come true, why not realize those aspirations at Honda?\n〈Software Defined Vehicle Business Development Unit, Digital Engine Development Division〉\nAt Honda, The Power of Dreams inspires us to create intelligent, connected products that enhance mobility and bring joy to people’s lives. Our goal is to deliver affordable, AI-powered solutions that \nmake customers smile—by combining cutting-edge technology, ethical transparency, and collaborative innovation. The automotive industry is undergoing a profound transformation. Vehicles are \nevolving from mere modes of transportation into intelligent, connected platforms that deliver new value to customers. To lead this shift, Honda is accelerating its efforts to build AI service platforms, \ndevelop core AI technologies, and create a data-driven development environment where data becomes a strategic asset for the entire organization. We are pioneering technical processes that \nenable rapid value validation, allowing us to test and deploy advanced AI technologies with speed and agility.\nOur team is global, highly motivated, and committed to shaping the future of mobility. We are now seeking new colleagues to help us explore the next generation of intelligent products and services. \nYour energy and creativity will help drive innovation forward. As part of this mission, we are advancing a Honda-style SDV (Software-Defined Vehicle) intelligence strategy, focused on building cost-\neffective AI development environments and strengthening partnerships around core technologies. Our diverse team already includes around 10 IIT graduates contributing their expertise.\nWe are currently looking for an innovative scientist with a strong background in Artificial Intelligence. Honda generates vast amounts of vehicle and customer data, and in this role, you will lead both \ntechnological research and real-world product development using this data. In this position, you won’t just be a scientist—you will act as a product owner, project manager, and business innovator. \nYou’ll develop and release AI-based services and continuously refine them through customer and vehicle feedback.\nWe value ambition, motivation, and a proactive approach to learning. Strong communication skills and a collaborative mindset are essential. We also hope you’ll connect with Honda’s founding \nphilosophy and help us bring it to life in everything we do.\nTo support this vision, we are building training ...
#  Document(metadata={'producer': 'Microsoft: Print To PDF', 'creator': 'PyPDF', 'creationdate': '2025-09-19T19:17:00+09:00', 'author': 'AtoJ-Ruchira', 'moddate': '2025-09-19T19:17:00+09:00', 'title': 'IITçŽ»é„²çﬂ¨Job Description(2025-2026)0903æ‘’å⁄º.xlsx', 'source': '..\\data\\pdf\\AI researcher.pdf', 'total_pages': 2, 'page': 1, 'page_label': '2', 'source file': 'AI researcher.pdf', 'file_type': 'pdf'}, page_content='UNDERGRAD\nCTC (Cost to \nCompany) 9,045,000 JPY\nCTC (breakdown)\n・Basic salary: 6,553,000 JPY \n・Allowance(Meal, Commuting, etc): 460,000 JPY\n・House Rent: 1,032,000 JPY *Guarantee fee will be deducted from salary\u3000 \n・JPN language lesson:  1,000,000 JPY\nTake Home (In Hand) 5,088,000 JPY *After tax\nGross Taxable \nIncome 6,553,000 -9,097,000JPY  *depend on Bonus\nMonthly Fixed Pay546,000 JPY （424,000 JPY *After tax）\nBonus\nAfter every 6 months of evaluation (CTC calculations are before tax):\n1. Output meets the assignments: no incentive (CTC: JPY 9,045,000)\n2. Outstanding outputs: additional bonus(*after tax) of JPY 636,000 (CTC: JPY 9,045,000+819,000) \n3. Supreme outputs: additional bonus(*after tax) of JPY 1,272,000 (CTC: JPY 9,045,000+1,638,000) \nSo maximum CTC a candidate can get after 1 year depending upon his performance is JPY 9,045,000+ 1,638,000+ 1,638,000 = 12,321,000JPY \nAllowances Commuting allowance,Meal allowance,Allowance Upon Joining(\\150,000, Flight Tickets, Moving Expense, Cost for initial VISA)\nNo overtime allowance\nHolidays Annual Paid Leaves:\u300020 days annually\nBenefits\nEmployment insurance\nWorkers’ Accident insurance           *Social insurance fee is deducted from salary.\nHealth insurance\nPension Insurance\nOfficial Working \nHours Base 8 hours / day\nPOSTGRAD\nCTC (Cost to \nCompany) 9,045,000 JPY\nCTC (breakdown)\n・Basic salary: 6,553,000 JPY \n・Allowance(Meal, Commuting, etc): 460,000 JPY\n・House Rent: 1,032,000 JPY *Guarantee fee will be deducted from salary\u3000 \n・JPN language lesson:  1,000,000 JPY\nTake Home (In Hand) 5,088,000 JPY *After tax\nGross Taxable \nIncome 6,553,000 -9,097,000JPY  *depend on Bonus\nMonthly Fixed Pay546,000 JPY （424,000 JPY *After tax）\nBonus\nAfter every 6 months of evaluation (CTC calculations are before tax):\n1. Output meets the assignments: no incentive (CTC: JPY 9,045,000)\n2. Outstanding outputs: additional bonus(*after tax) of JPY 636,000 (CTC: JPY 9,045,000+819,000) \n3. Supreme outputs: additional bonus(*after tax) of JPY 1,272,000 (CTC: JPY 9,045,000+1,638,000) \nSo maximum CTC a candidate can get after 1 year depending upon his performance is JPY 9,045,000+ 1,638,000+ 1,638,000 = 12,321,000JPY \nAllowances Commuting allowance,Meal allowance,Allowance Upon Joining(\\150,000, Flight Tickets, Moving Expense, Cost for initial VISA)\nNo overtime allowance\nHolidays Annual Paid Leaves:\u300020 days annually\nBenefits\nEmployment insurance\nWorkers’ Accident insurance           *Social insurance fee is deducted from salary.\nHealth insurance\nPension Insurance\nOfficial Working \nHours Base 8 hours / day'),
#  Document(metadata={'producer': 'macOS Version 15.7.1 (Build 24G231) Quartz PDFContext', 'creator': 'Pages', 'creationdate': "D:20251104070722Z00'00'", 'title': 'JD-Machine Learning Engineer', 'moddate': "D:20251104070722Z00'00'", 'source': '..\\data\\pdf\\apple_jd.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1', 'source file': 'apple_jd.pdf', 'file_type': 'pdf'}, page_content='Machine Learning Engineer \nLocation: Bangalore\nJob Description \nAre you interested in applying your quantitative skills in a fast paced tech environment? \nIf so, then this is the job for you. The Worldwide Sales and Operations Advanced \nAnalytics team is looking for an experienced Machine Learning Scientist with a deep \npassion for analytical solutions that have direct and measurable impact to Apple and its \ncustomers. You will design, build and deploy predictive and prescriptive end-to-end \nsolutions for strategic and tactical supply chain decision-making.\nYou will be part of a team of experts responsible for delivering data analytics and AI/ML/\nGenAI Solutions at scale to the organization. You will be working closely with business \nstakeholders, other data scientists, and IT groups in incorporating the essential tradeoffs \nwithin the models and take an active role in effectively communicating the \nrecommendations to senior management. This is an exciting opportunity to understand \nApple’s Supply Chain dynamics and apply your quantitative and analytical skills to \ninﬂuence data-driven decisions at scale.\nThe role involves building applications harnessing large amounts of data across all of \nApple’s products, leveraging AI/ML and large language models.\nQUALIFICATIONS\n• Desire to solve real-world problems and a strong understanding of machine learning \nconcepts.\n• Ability to implement data science pipelines and applications in a general \nprogramming language such as Python, Scala, Java or C++\n• Hands on knowledge with database modeling, data warehousing principles and SQL\n• Ability to comprehend and debug complex systems integrations spanning tools and \nteams. Strong critical thinking and problem solving ability\n• Sound communication skills - adept at messaging domain and technical content, at a \nlevel appropriate for the audience.\n• Experienced at understanding key performance levers and metrics to highlight \noperational issues and drive improvement\n• Innate curiosity and bias to action with expert ability to identify, deﬁne and execute \nproject plans and develop modeling approaches suitable for the problem\n• Strong team player - invested in the collective success of the team and project \noutcomes\n• Self-sufﬁcient with an ability to thrive in an environment of autonomy amidst ambiguity\nEDUCATION\n• Masters/Dual Degree in Department of Data Science and AI, Computer Science, \nInformation Science (with focus on AI/ML, GenAI and Analytics)'),
#  Document(metadata={'producer': 'Microsoft: Print To PDF', 'creator': 'PyPDF', 'creationdate': '2025-09-19T19:15:31+09:00', 'author': 'AtoJ-Ruchira', 'moddate': '2025-09-19T19:15:31+09:00', 'title': 'IITçŽ»é„²çﬂ¨Job Description(2025-2026)0903æ‘’å⁄º.xlsx', 'source': '..\\data\\pdf\\Applied Data Scientist.pdf', 'total_pages': 2, 'page': 0, 'page_label': '1', 'source file': 'Applied Data Scientist.pdf', 'file_type': 'pdf'}, page_content='Honda Motor Co., \nLtd.\nSkills\n【Required Experience and Skills】\nApplicants should possess experience and strong foundation in modern Data Science\n【Preferred Experience and Skills】\nIn addition to the above, the following experience and skills are desirable:\n- Experience in deriving value through data science and mathematical modeling.\n- Experience in spatiotemporal analysis of probe data and sensing data.\n- Knowledge or development experience related to autonomous driving and advanced driver-assistance systems (ADAS).\n- English communication skills.\n- Experience in project management, etc.\n【Ideal Candidate Profile】\nWe are looking for individuals who:\n- Are highly motivated to contribute to Honda’s AD/ADAS development and new business domains such as recurring revenue through data analysis.\n- Are eager to respond quickly to customer and market needs, and continuously improve operations and products with an agile mindset.\n- Proactively engage and collaborate with internal and external stakeholders.\nApplied Data Scientist\nJob Description\nHonda is a total mobility company dedicated to delivering the "joy of free movement." We innovate in various fields, including motorcycles, automobiles, \npower products, aircraft and aircraft engines, and robotics. Honda operates in markets across about 200 countries worldwide, continuously creating next-\ngeneration mobility solutions and products that improve people’s lives by combining our technology and expertise.\nAt Honda, everyone, regardless of nationality, gender, educational background, or experience, can freely express their ideas. Since our founding, we have \nmaintained the ambition of asking, "What can we do for the world and for people?"\nWe believe that having dreams and staying passionate about making them a reality is the reason Honda exists. "It\'s not about what happens; it\'s about what \nyou do." You are the ones who will shape the future of the world. As you move forward in life, we hope you will be the main character in the moments when \nthe world changes.\nIf you have a desire to achieve something, to create something, or to make your dreams come true, why not realize those aspirations at Honda?\n〈Software Defined Mobility Development Supervisory Unit, Advanced Safety and Intelligent Solution Development Division〉\nOur mission is to develop world-leading safety features and autonomous driving systems, and to deliver the safest vehicles in the world. Honda\'s AD/ADAS \nData Platform Group provides an ecosystem for AD/ADAS system development to analyze and test safety and functionality through simulations, insight and \nanalysis of sensing data from test vehicles. The ecosystem is used in the critical process of validating the results of functional development and obtaining \n“type certification”. \nIn this division, the engineers who developed the world’s first Level 3 automated driving system are continuously researching and commercializing cutting-\nedge technologies. Through the development of Level 3 autonomous driving systems, Honda has gained access to valuable market data from both customer \nand test vehicles. This data is utilized to improve safety validation, product planning, and functional design. The results of your analysis will be applied \nglobally through Honda’s extensive international network, contributing to the realization of a society with zero traffic fatalities.\nTo increase the number of people who smile through their experience with cars, we are seeking teammates who will lead Honda’s global four-w ...
#  Document(metadata={'producer': 'Microsoft: Print To PDF', 'creator': 'PyPDF', 'creationdate': '2025-09-19T19:15:31+09:00', 'author': 'AtoJ-Ruchira', 'moddate': '2025-09-19T19:15:31+09:00', 'title': 'IITçŽ»é„²çﬂ¨Job Description(2025-2026)0903æ‘’å⁄º.xlsx', 'source': '..\\data\\pdf\\Applied Data Scientist.pdf', 'total_pages': 2, 'page': 1, 'page_label': '2', 'source file': 'Applied Data Scientist.pdf', 'file_type': 'pdf'}, page_content='UNDERGRAD\nCTC (Cost to \nCompany)\nCTC (breakdown)\nTake Home (In Hand)\nGross Taxable \nIncome\nMonthly Fixed Pay\nBonus\nAllowances\nHolidays\nBenefits\nOfficial Working \nHours\nPOSTGRAD\nCTC (Cost to \nCompany)\nCTC (breakdown)\nTake Home (In Hand)\nGross Taxable \nIncome\nMonthly Fixed Pay\nBonus\nAllowances\nHolidays\nBenefits\nOfficial Working \nHours\nAfter every 6 months of evaluation:  (CTC calculations are before tax):\n1. Output meets the assignments: no incentive (CTC: JPY 8,757,000) \n2. Outstanding outputs: additional bonus(*after tax) of JPY 636,000 (CTC: JPY 8,757,000+819,000) \n3. Supreme outputs: additional bonus(*after tax) of JPY 1,272,000 (CTC: JPY 8,757,000+1,638,000) \nSo maximum CTC a candidate can get after 1 year depending upon his performance is JPY 8,757,000+ 1,638,000+ 1,638,000 =12,033,000JPY\nCommuting allowance,Meal allowance,Allowance Upon Joining\n(\\150,000, Flight Tickets, Moving Expense, Cost for initial VISA)\nNo overtime allowance\nAnnual Paid Leaves:\u300020 days annually\nEmployment insurance\nWorkers’ Accident insurance           *Social insurance fee is deducted from salary.\nHealth insurance\nPension Insurance\nBase 8 hours / day\n8,757,000 JPY\n・Basic salary: 6,553,000 JPY \n5,088,000 JPY *After tax\n6,553,000 -9,097,000JPY  *depend on Bonus\n546,000 JPY （424,000 JPY *After tax）\n546,000 JPY （424,000 JPY *After tax）\nAfter every 6 months of evaluation:  (CTC calculations are before tax):\n1. Output meets the assignments: no incentive (CTC: JPY 8,757,000) \n2. Outstanding outputs: additional bonus(*after tax) of JPY 636,000 (CTC: JPY 8,757,000+819,000) \n3. Supreme outputs: additional bonus(*after tax) of JPY 1,272,000 (CTC: JPY 8,757,000+1,638,000) \nSo maximum CTC a candidate can get after 1 year depending upon his performance is JPY 8,757,000+ 1,638,000+ 1,638,000 =12,033,000JPY\nCommuting allowance,Meal allowance,Allowance Upon Joining(\\150,000, Flight Tickets, Moving Expense, Cost for initial VISA)\nNo overtime allowance\nAnnual Paid Leaves:\u300020 days annually\nEmployment insurance\nWorkers’ Accident insurance           *Social insurance fee is deducted from salary.\nHealth insurance\nPension Insurance\nBase 8 hours / day\n8,757,000 JPY\n・Basic salary: 6,553,000 JPY \n・Allowance(Meal, Commuting, etc): 460,000 JPY\n・House Rent: 744,000 JPY\u3000 *Guarantee fee will be deducted from salary\u3000 \n・JPN language lesson:  1,000,000 JPYE75\n5,088,000 JPY *After tax\n6,553,000 -9,097,000JPY  *depend on Bonus'),
#  Document(metadata={'producer': 'Microsoft: Print To PDF', 'creator': 'PyPDF', 'creationdate': '2025-09-19T19:16:02+09:00', 'author': 'AtoJ-Ruchira', 'moddate': '2025-09-19T19:16:02+09:00', 'title': 'IITçŽ»é„²çﬂ¨Job Description(2025-2026)0903æ‘’å⁄º.xlsx', 'source': '..\\data\\pdf\\Data Engineer.pdf', 'total_pages': 2, 'page': 0, 'page_label': '1', 'source file': 'Data Engineer.pdf', 'file_type': 'pdf'}, page_content='Honda Motor Co., \nLtd. Data Engineer\nHonda is a total mobility company dedicated to delivering the "joy of free movement." We innovate in various fields, including motorcycles, automobiles, power products, aircraft \nand aircraft engines, and robotics. Honda operates in markets across about 200 countries worldwide, continuously creating next-generation mobility solutions and products that \nimprove people’s lives by combining our technology and expertise.\nAt Honda, everyone, regardless of nationality, gender, educational background, or experience, can freely express their ideas. Since our founding, we have maintained the ambition of \nasking, "What can we do for the world and for people?"\nWe believe that having dreams and staying passionate about making them a reality is the reason Honda exists. "It\'s not about what happens; it\'s about what you do." You are the \nones who will shape the future of the world. As you move forward in life, we hope you will be the main character in the moments when the world changes.\nIf you have a desire to achieve something, to create something, or to make your dreams come true, why not realize those aspirations at Honda?\n〈Software Defined Mobility Development Supervisory Unit, Advanced Safety and Intelligent Solution Development Division〉\nOur mission is to develop world-leading safety features and autonomous driving systems, and to deliver the safest vehicles in the world. Honda\'s AD/ADAS Data Platform Group \nprovides an ecosystem for AD/ADAS system development to analyze and test safety and functionality through simulations, insight and analysis of sensing data from test vehicles. The \necosystem is used in the critical process of validating the results of functional development and obtaining “type certification”. \nIn this division, the engineers who developed the world’s first Level 3 automated driving system are continuously researching and commercializing cutting-edge technologies. \nThrough the development of Level 3 autonomous driving systems, Honda has gained access to valuable market data from both customer and test vehicles. This data is utilized to \nimprove safety validation, product planning, and functional design. The results of your analysis will be applied globally through Honda’s extensive international network, contributing \nto the realization of a society with zero traffic fatalities.\nTo increase the number of people who smile through their experience with cars, we are seeking teammates who will lead Honda’s global four-wheel development—from \nfoundational product development optimized for each region to cutting-edge technology innovation. As of July 2025, there are currently 10 Indian engineers and 2 Chinese engineers \non the team. An additional 6 engineers—all graduates of IIT (Indian Institutes of Technology)—are scheduled to join in October 2025.\nEmployees who proactively engage with their work and demonstrate strong initiative are entrusted with major responsibilities, even shortly after joining. We welcome individuals \nwith the drive to raise their hand and launch projects with the spirit of “I want to create this kind of technology!”\n <Responsibilities> \n- Learn and understand existing workflows and system configurations for model-in-the-loop (MIL) simulation, data analysis, and testing.\n- Continuously propose improvements to data analysis methods and approaches for better summarization and insight generation.\n- Develop analysis and ETL/ELT pipelines following industry-standard practices.\n- Create self-contained solutions that can be bu ...
#  Document(metadata={'producer': 'Microsoft: Print To PDF', 'creator': 'PyPDF', 'creationdate': '2025-09-19T19:16:02+09:00', 'author': 'AtoJ-Ruchira', 'moddate': '2025-09-19T19:16:02+09:00', 'title': 'IITçŽ»é„²çﬂ¨Job Description(2025-2026)0903æ‘’å⁄º.xlsx', 'source': '..\\data\\pdf\\Data Engineer.pdf', 'total_pages': 2, 'page': 1, 'page_label': '2', 'source file': 'Data Engineer.pdf', 'file_type': 'pdf'}, page_content='UNDERGRAD\nCTC (Cost to \nCompany) 8,757,000 JPY\nCTC (breakdown)\n・Basic salary: 6,553,000 JPY \n・Allowance(Meal, Commuting, etc): 460,000 JPY\n・House Rent: 744,000 JPY\u3000 *Guarantee fee will be deducted from salary\u3000 \n・JPN language lesson:  1,000,000 JPY\nTake Home (In Hand) 5,088,000 JPY *After tax\nGross Taxable \nIncome 6,553,000 -9,097,000JPY  *depend on Bonus\nMonthly Fixed Pay546,000 JPY （424,000 JPY *After tax）\nBonus\nAfter every 6 months of evaluation:  (CTC calculations are before tax):\n1. Output meets the assignments: no incentive (CTC: JPY 8,757,000) \n2. Outstanding outputs: additional bonus(*after tax) of JPY 636,000 (CTC: JPY 8,757,000+819,000) \n3. Supreme outputs: additional bonus(*after tax) of JPY 1,272,000 (CTC: JPY 8,757,000+1,638,000) \nSo maximum CTC a candidate can get after 1 year depending upon his performance is JPY 8,757,000+ 1,638,000+ 1,638,000 =12,033,000JPY\nAllowances Commuting allowance,Meal allowance,Allowance Upon Joining(\\150,000, Flight Tickets, Moving Expense, Cost for initial VISA)\nNo overtime allowance\nHolidays Annual Paid Leaves:\u300020 days annually\nBenefits\nEmployment insurance\nWorkers’ Accident insurance           *Social insurance fee is deducted from salary.\nHealth insurance\nPension Insurance\nOfficial Working \nHours Base 8 hours / day\nPOSTGRAD\nCTC (Cost to \nCompany) 8,757,000 JPY\nCTC (breakdown)\n・Basic salary: 6,553,000 JPY \n・Allowance(Meal, Commuting, etc): 460,000 JPY\n・House Rent: 744,000 JPY\u3000 *Guarantee fee will be deducted from salary\u3000 \n・JPN language lesson:  1,000,000 JPY\nTake Home (In Hand) 5,088,000 JPY *After tax\nGross Taxable \nIncome 6,553,000 -9,097,000JPY  *depend on Bonus\nMonthly Fixed Pay546,000 JPY （424,000 JPY *After tax）\nBonus\nAfter every 6 months of evaluation:  (CTC calculations are before tax):\n1. Output meets the assignments: no incentive (CTC: JPY 8,757,000) \n2. Outstanding outputs: additional bonus(*after tax) of JPY 636,000 (CTC: JPY 8,757,000+819,000) \n3. Supreme outputs: additional bonus(*after tax) of JPY 1,272,000 (CTC: JPY 8,757,000+1,638,000) \nSo maximum CTC a candidate can get after 1 year depending upon his performance is JPY 8,757,000+ 1,638,000+ 1,638,000 =12,033,000JPY\nAllowances Commuting allowance,Meal allowance,Allowance Upon Joining(\\150,000, Flight Tickets, Moving Expense, Cost for initial VISA)\nNo overtime allowance\nHolidays Annual Paid Leaves:\u300020 days annually\nBenefits\nEmployment insurance\nWorkers’ Accident insurance           *Social insurance fee is deducted from salary.\nHealth insurance\nPension Insurance\nOfficial Working \nHours Base 8 hours / day'),
#  Document(metadata={'producer': 'Microsoft: Print To PDF', 'creator': 'PyPDF', 'creationdate': '2025-09-19T19:16:30+09:00', 'author': 'AtoJ-Ruchira', 'moddate': '2025-09-19T19:16:30+09:00', 'title': 'IITçŽ»é„²çﬂ¨Job Description(2025-2026)0903æ‘’å⁄º.xlsx', 'source': '..\\data\\pdf\\DNN Developer.pdf', 'total_pages': 2, 'page': 0, 'page_label': '1', 'source file': 'DNN Developer.pdf', 'file_type': 'pdf'}, page_content='Honda Motor Co., \nLtd. Deep Neural Network (DNN) Development Engineer\nHonda is a total mobility company dedicated to delivering the "joy of free movement." We innovate in various fields, including motorcycles, automobiles, power products, aircraft \nand aircraft engines, and robotics. Honda operates in markets across about 200 countries worldwide, continuously creating next-generation mobility solutions and products that \nimprove people’s lives by combining our technology and expertise.\nAt Honda, everyone, regardless of nationality, gender, educational background, or experience, can freely express their ideas. Since our founding, we have maintained the ambition of \nasking, "What can we do for the world and for people?"\nWe believe that having dreams and staying passionate about making them a reality is the reason Honda exists. "It\'s not about what happens; it\'s about what you do." You are the \nones who will shape the future of the world. As you move forward in life, we hope you will be the main character in the moments when the world changes.\nIf you have a desire to achieve something, to create something, or to make your dreams come true, why not realize those aspirations at Honda?\n〈Software Defined Mobility Development Supervisory Unit, Advanced Safety and Intelligent Solution Development Division〉\nHonda\'s Software Defined Mobility Development Supervisory Unit is committed to pursuing innovative development and creation of “value” in mobility and life. We aim for “Zero \ntraffic collision fatalities” involving Honda motorcycles or automobiles worldwide in 2050. The AD/ADAS division is responsible for the development of safety functions such as Honda \nSensing Elite and Honda sensing 360 for this purpose. In this division, the engineers who realized the world\'s first LV3 automated driving system are constantly researching and \ncommercializing the latest technologies.\nOur mission is to develop world-leading safety features and autonomous driving systems and to deliver the safest vehicles in the world. This represents a significant shift from \nconventional automobiles and demands innovation, particularly through the application of AI technologies. It is a field that requires deep technical exploration and a spirit of \nchallenge.\nWe offer an environment where you can engage in global research and development in collaboration with Honda’s overseas offices, universities, and companies. We are looking for \nteammates who possess specialized technologies that contribute to major transformations and innovations in mobility—and who are eager not only to conduct research but also to \nbring their work into the real world and make a meaningful contribution to society.\nYou will be responsible for developing one or more of the following technologies related to next-generation development of driver assistance and autonomous driving systems:\n- Image recognition algorithms and machine learning models for object and lane recognition\n- Traffic environment understanding algorithms and machine learning models using recognition data\n- Behavior planning algorithms and machine learning models based on traffic conditions\n- Edge device deployment of machine learning models \n- Multimodal fusion technologies using cameras and other external sensing devices\n- Driver state and in-cabin recognition using DNNs and LLMs\n- Self-localization and automated map generation \n- MLOps environment construction\n- Optimization, probabilistic inference, and data mining\nYou will also be involved in R&D of AI-based functions for a ...
#  Document(metadata={'producer': 'Microsoft: Print To PDF', 'creator': 'PyPDF', 'creationdate': '2025-09-19T19:16:30+09:00', 'author': 'AtoJ-Ruchira', 'moddate': '2025-09-19T19:16:30+09:00', 'title': 'IITçŽ»é„²çﬂ¨Job Description(2025-2026)0903æ‘’å⁄º.xlsx', 'source': '..\\data\\pdf\\DNN Developer.pdf', 'total_pages': 2, 'page': 1, 'page_label': '2', 'source file': 'DNN Developer.pdf', 'file_type': 'pdf'}, page_content='UNDERGRAD\nCTC (Cost to \nCompany) 9,045,000 JPY\nCTC (breakdown)\n・Basic salary: 6,553,000 JPY \n・Allowance(Meal, Commuting, etc): 460,000 JPY\n・House Rent: 1,032,000 JPY *Guarantee fee will be deducted from salary\u3000 \n・JPN language lesson:  1,000,000 JPY\nTake Home (In Hand) 5,088,000 JPY *After tax\nGross Taxable \nIncome 6,553,000 -9,097,000JPY  *depend on Bonus\nMonthly Fixed Pay546,000 JPY （424,000 JPY *After tax）\nBonus\nAfter every 6 months of evaluation (CTC calculations are before tax):\n1. Output meets the assignments: no incentive (CTC: JPY 9,045,000)\n2. Outstanding outputs: additional bonus(*after tax) of JPY 636,000 (CTC: JPY 9,045,000+819,000) \n3. Supreme outputs: additional bonus(*after tax) of JPY 1,272,000 (CTC: JPY 9,045,000+1,638,000) \nSo maximum CTC a candidate can get after 1 year depending upon his performance is JPY 9,045,000+ 1,638,000+ 1,638,000 = 12,321,000JPY \nAllowances Commuting allowance,Meal allowance,Allowance Upon Joining(\\150,000, Flight Tickets, Moving Expense, Cost for initial VISA)\nNo overtime allowance\nHolidays Annual Paid Leaves:\u300020 days annually\nBenefits\nEmployment insurance\nWorkers’ Accident insurance           *Social insurance fee is deducted from salary.\nHealth insurance\nPension Insurance\nOfficial Working \nHours Base 8 hours / day\nPOSTGRAD\nCTC (Cost to \nCompany) 9,045,000 JPY\nCTC (breakdown)\n・Basic salary: 6,553,000 JPY \n・Allowance(Meal, Commuting, etc): 460,000 JPY\n・House Rent: 1,032,000 JPY *Guarantee fee will be deducted from salary\u3000 \n・JPN language lesson:  1,000,000 JPY\nTake Home (In Hand) 5,088,000 JPY *After tax\nGross Taxable \nIncome 6,553,000 -9,097,000JPY  *depend on Bonus\nMonthly Fixed Pay546,000 JPY （424,000 JPY *After tax）\nBonus\nAfter every 6 months of evaluation (CTC calculations are before tax):\n1. Output meets the assignments: no incentive (CTC: JPY 9,045,000)\n2. Outstanding outputs: additional bonus(*after tax) of JPY 636,000 (CTC: JPY 9,045,000+819,000) \n3. Supreme outputs: additional bonus(*after tax) of JPY 1,272,000 (CTC: JPY 9,045,000+1,638,000) \nSo maximum CTC a candidate can get after 1 year depending upon his performance is JPY 9,045,000+ 1,638,000+ 1,638,000 = 12,321,000JPY \nAllowances Commuting allowance,Meal allowance,Allowance Upon Joining(\\150,000, Flight Tickets, Moving Expense, Cost for initial VISA)\nNo overtime allowance\nHolidays Annual Paid Leaves:\u300020 days annually\nBenefits\nEmployment insurance\nWorkers’ Accident insurance           *Social insurance fee is deducted from salary.\nHealth insurance\nPension Insurance\nOfficial Working \nHours Base 8 hours / day')]

# %% [markdown]
# #### 2. Chunking
#
# **Chunking the documents is done soley because embedding models have a context size. We can only feed them data in smaller segments**

# %%
### Text splitting get into chunks 

def split_documents(documents, chunk_size = 1000, chunk_overlap = 200):
    """Split documents into smaller chunks for better RAG performance"""

    text_splitter = RecursiveCharacterTextSplitter(
        chunk_size = chunk_size,
        chunk_overlap = chunk_overlap,
        length_function = len,
        separators = ["\n\n", "\n", " ", ""]
    )

    split_docs = text_splitter.split_documents(documents)
    print(f"Split {len(documents)} documents into {len(split_docs)} chunks")

    # Show example of a chunk
    if split_docs:
        print(f"\nExample chunk:")
        print(f"Content: {split_docs[0].page_content[:200]}...")
        print(f"Metadata: {split_docs[0].metadata}")
    
    return split_docs

# %%
chunks = split_documents(all_pdf_documents)
chunks
# Out:
# Split 9 documents into 49 chunks
#
# Example chunk:
# Content: Honda Motor Co.,
# Ltd. AI Research Engineer
# Honda is a total mobility company dedicated to delivering the "joy of free movement." We innovate in various fields, including motorcycles, automobiles, pow...
# Metadata: {'producer': 'Microsoft: Print To PDF', 'creator': 'PyPDF', 'creationdate': '2025-09-19T19:17:00+09:00', 'author': 'AtoJ-Ruchira', 'moddate': '2025-09-19T19:17:00+09:00', 'title': 'IITçŽ»é„²çﬂ¨Job Description(2025-2026)0903æ‘’å⁄º.xlsx', 'source': '..\\data\\pdf\\AI researcher.pdf', 'total_pages': 2, 'page': 0, 'page_label': '1', 'source file': 'AI researcher.pdf', 'file_type': 'pdf'}
# [Document(metadata={'producer': 'Microsoft: Print To PDF', 'creator': 'PyPDF', 'creationdate': '2025-09-19T19:17:00+09:00', 'author': 'AtoJ-Ruchira', 'moddate': '2025-09-19T19:17:00+09:00', 'title': 'IITçŽ»é„²çﬂ¨Job Description(2025-2026)0903æ‘’å⁄º.xlsx', 'source': '..\\data\\pdf\\AI researcher.pdf', 'total_pages': 2, 'page': 0, 'page_label': '1', 'source file': 'AI researcher.pdf', 'file_type': 'pdf'}, page_content='Honda Motor Co., \nLtd. AI Research Engineer\nHonda is a total mobility company dedicated to delivering the "joy of free movement." We innovate in various fields, including motorcycles, automobiles, power products, aircraft and aircraft \nengines, and robotics. Honda operates in markets across about 200 countries worldwide, continuously creating next-generation mobility solutions and products that improve people’s lives by \ncombining our technology and expertise.\nAt Honda, everyone, regardless of nationality, gender, educational background, or experience, can freely express their ideas. Since our founding, we have maintained the ambition of asking, "What \ncan we do for the world and for people?"\nWe believe that having dreams and staying passionate about making them a reality is the reason Honda exists. "It\'s not about what happens; it\'s about what you do." You are the ones who will shape'),
#  Document(metadata={'producer': 'Microsoft: Print To PDF', 'creator': 'PyPDF', 'creationdate': '2025-09-19T19:17:00+09:00', 'author': 'AtoJ-Ruchira', 'moddate': '2025-09-19T19:17:00+09:00', 'title': 'IITçŽ»é„²çﬂ¨Job Description(2025-2026)0903æ‘’å⁄º.xlsx', 'source': '..\\data\\pdf\\AI researcher.pdf', 'total_pages': 2, 'page': 0, 'page_label': '1', 'source file': 'AI researcher.pdf', 'file_type': 'pdf'}, page_content='We believe that having dreams and staying passionate about making them a reality is the reason Honda exists. "It\'s not about what happens; it\'s about what you do." You are the ones who will shape \nthe future of the world. As you move forward in life, we hope you will be the main character in the moments when the world changes.\nIf you have a desire to achieve something, to create something, or to make your dreams come true, why not realize those aspirations at Honda?\n〈Software Defined Vehicle Business Development Unit, Digital Engine Development Division〉\nAt Honda, The Power of Dreams inspires us to create intelligent, connected products that enhance mobility and bring joy to people’s lives. Our goal is to deliver affordable, AI-powered solutions that \nmake customers smile—by combining cutting-edge technology, ethical transparency, and collaborative innovation. The automotive industry is undergoing a profound transformation. Vehicles are'),
#  Document(metadata={'producer': 'Microsoft: Print To PDF', 'creator': 'PyPDF', 'creationdate': '2025-09-19T19:17:00+09:00', 'author': 'AtoJ-Ruchira', 'moddate': '2025-09-19T19:17:00+09:00', 'title': 'IITçŽ»é„²çﬂ¨Job Description(2025-2026)0903æ‘’å⁄º.xlsx', 'source': '..\\data\\pdf\\AI researcher.pdf', 'total_pages': 2, 'page': 0, 'page_label': '1', 'source file': 'AI researcher.pdf', 'file_type': 'pdf'}, page_content='make customers smile—by combining cutting-edge technology, ethical transparency, and collaborative innovation. The automotive industry is undergoing a profound transformation. Vehicles are \nevolving from mere modes of transportation into intelligent, connected platforms that deliver new value to customers. To lead this shift, Honda is accelerating its efforts to build AI service platforms, \ndevelop core AI technologies, and create a data-driven development environment where data becomes a strategic asset for the entire organization. We are pioneering technical processes that \nenable rapid value validation, allowing us to test and deploy advanced AI technologies with speed and agility.\nOur team is global, highly motivated, and committed to shaping the future of mobility. We are now seeking new colleagues to help us explore the next generation of intelligent products and services.'),
#  Document(metadata={'producer': 'Microsoft: Print To PDF', 'creator': 'PyPDF', 'creationdate': '2025-09-19T19:17:00+09:00', 'author': 'AtoJ-Ruchira', 'moddate': '2025-09-19T19:17:00+09:00', 'title': 'IITçŽ»é„²çﬂ¨Job Description(2025-2026)0903æ‘’å⁄º.xlsx', 'source': '..\\data\\pdf\\AI researcher.pdf', 'total_pages': 2, 'page': 0, 'page_label': '1', 'source file': 'AI researcher.pdf', 'file_type': 'pdf'}, page_content='Our team is global, highly motivated, and committed to shaping the future of mobility. We are now seeking new colleagues to help us explore the next generation of intelligent products and services. \nYour energy and creativity will help drive innovation forward. As part of this mission, we are advancing a Honda-style SDV (Software-Defined Vehicle) intelligence strategy, focused on building cost-\neffective AI development environments and strengthening partnerships around core technologies. Our diverse team already includes around 10 IIT graduates contributing their expertise.\nWe are currently looking for an innovative scientist with a strong background in Artificial Intelligence. Honda generates vast amounts of vehicle and customer data, and in this role, you will lead both \ntechnological research and real-world product development using this data. In this position, you won’t just be a scientist—you will act as a product owner, project manager, and business innovator.'),
#  Document(metadata={'producer': 'Microsoft: Print To PDF', 'creator': 'PyPDF', 'creationdate': '2025-09-19T19:17:00+09:00', 'author': 'AtoJ-Ruchira', 'moddate': '2025-09-19T19:17:00+09:00', 'title': 'IITçŽ»é„²çﬂ¨Job Description(2025-2026)0903æ‘’å⁄º.xlsx', 'source': '..\\data\\pdf\\AI researcher.pdf', 'total_pages': 2, 'page': 0, 'page_label': '1', 'source file': 'AI researcher.pdf', 'file_type': 'pdf'}, page_content="technological research and real-world product development using this data. In this position, you won’t just be a scientist—you will act as a product owner, project manager, and business innovator. \nYou’ll develop and release AI-based services and continuously refine them through customer and vehicle feedback.\nWe value ambition, motivation, and a proactive approach to learning. Strong communication skills and a collaborative mindset are essential. We also hope you’ll connect with Honda’s founding \nphilosophy and help us bring it to life in everything we do.\nTo support this vision, we are building training programs and promoting research themes worthy of academic publication, ensuring our team is prepared to compete on the global stage.\n■Position / Job Description\n• Participate in existing projects and learn Honda's business processes, key stakeholders, and philosophy to eventually become an independent project leader."),
#  Document(metadata={'producer': 'Microsoft: Print To PDF', 'creator': 'PyPDF', 'creationdate': '2025-09-19T19:17:00+09:00', 'author': 'AtoJ-Ruchira', 'moddate': '2025-09-19T19:17:00+09:00', 'title': 'IITçŽ»é„²çﬂ¨Job Description(2025-2026)0903æ‘’å⁄º.xlsx', 'source': '..\\data\\pdf\\AI researcher.pdf', 'total_pages': 2, 'page': 0, 'page_label': '1', 'source file': 'AI researcher.pdf', 'file_type': 'pdf'}, page_content="■Position / Job Description\n• Participate in existing projects and learn Honda's business processes, key stakeholders, and philosophy to eventually become an independent project leader.\n• Identify both existing and new research problems by interacting with Honda team members. Help refine research methodology by sharing research trends and best practices within the community.\n• Actively collaborate with business, product, marketing, UX, and other internal stakeholders to create functional requirements and propose new projects that could be of value to customers.\n• Develop new algorithms for the utilization of AI both outside and inside the car using vari+B1ous sensors.\n• Define the data structure, framework, design, and evaluation metrics for research solution development and implementation.\n• Drive R&D projects toward strategic product decisions through quick iterations of experimentation and PoC."),
#  Document(metadata={'producer': 'Microsoft: Print To PDF', 'creator': 'PyPDF', 'creationdate': '2025-09-19T19:17:00+09:00', 'author': 'AtoJ-Ruchira', 'moddate': '2025-09-19T19:17:00+09:00', 'title': 'IITçŽ»é„²çﬂ¨Job Description(2025-2026)0903æ‘’å⁄º.xlsx', 'source': '..\\data\\pdf\\AI researcher.pdf', 'total_pages': 2, 'page': 0, 'page_label': '1', 'source file': 'AI researcher.pdf', 'file_type': 'pdf'}, page_content='• Drive R&D projects toward strategic product decisions through quick iterations of experimentation and PoC.\n• Manage all project planning and execution from the launch of the project to the delivery of the product to the customer.\n• Author research papers and apply for patents to share and generate impact from research results across the team and within the research community.\n• Perform basic project management routines including scheduling, cost management, stakeholder relationship management, and service health and performance monitoring.\n■Key Highlights\n・A new software studio and stylish office in a modern city.\n・Development of actual AI-powered consumer services that will be used by Honda customers.\n・Access to real vehicles and vehicle data as Honda’s proprietary assets.\nRequired Skills\n- Proficiency in Python, C++, or other programming languages\n- Functional knowledge of cloud platforms such as AWS, Azure, and GCP'),
#  Document(metadata={'producer': 'Microsoft: Print To PDF', 'creator': 'PyPDF', 'creationdate': '2025-09-19T19:17:00+09:00', 'author': 'AtoJ-Ruchira', 'moddate': '2025-09-19T19:17:00+09:00', 'title': 'IITçŽ»é„²çﬂ¨Job Description(2025-2026)0903æ‘’å⁄º.xlsx', 'source': '..\\data\\pdf\\AI researcher.pdf', 'total_pages': 2, 'page': 0, 'page_label': '1', 'source file': 'AI researcher.pdf', 'file_type': 'pdf'}, page_content='Required Skills\n- Proficiency in Python, C++, or other programming languages\n- Functional knowledge of cloud platforms such as AWS, Azure, and GCP\n- Deep understanding of data, application, server, and network security\n- Data modeling skills and experience with SQL using Oracle, MySQL, and columnar databases\n- Familiarity with machine learning frameworks such as PyTorch and TensorFlow\n- Experience in training and deploying vision-based AI models\nPreferred Skills\n- Research experience using LLMs with RAG, VLM, or model fine-tuning\n- Basic understanding of user-centric product design\n- Experience in successful university projects implementing the above technologies (Real-world deployment preferred)\nCore Human Qualities \n- Ethics, compliance, courtesy, punctuality, and meeting deadlines\n- Positive mindset and sincerity\n- Language acquisition ability\n- Experience in cross-cultural communication\nJob Description\nSkills'),
#  Document(metadata={'producer': 'Microsoft: Print To PDF', 'creator': 'PyPDF', 'creationdate': '2025-09-19T19:17:00+09:00', 'author': 'AtoJ-Ruchira', 'moddate': '2025-09-19T19:17:00+09:00', 'title': 'IITçŽ»é„²çﬂ¨Job Description(2025-2026)0903æ‘’å⁄º.xlsx', 'source': '..\\data\\pdf\\AI researcher.pdf', 'total_pages': 2, 'page': 1, 'page_label': '2', 'source file': 'AI researcher.pdf', 'file_type': 'pdf'}, page_content='UNDERGRAD\nCTC (Cost to \nCompany) 9,045,000 JPY\nCTC (breakdown)\n・Basic salary: 6,553,000 JPY \n・Allowance(Meal, Commuting, etc): 460,000 JPY\n・House Rent: 1,032,000 JPY *Guarantee fee will be deducted from salary\u3000 \n・JPN language lesson:  1,000,000 JPY\nTake Home (In Hand) 5,088,000 JPY *After tax\nGross Taxable \nIncome 6,553,000 -9,097,000JPY  *depend on Bonus\nMonthly Fixed Pay546,000 JPY （424,000 JPY *After tax）\nBonus\nAfter every 6 months of evaluation (CTC calculations are before tax):\n1. Output meets the assignments: no incentive (CTC: JPY 9,045,000)\n2. Outstanding outputs: additional bonus(*after tax) of JPY 636,000 (CTC: JPY 9,045,000+819,000) \n3. Supreme outputs: additional bonus(*after tax) of JPY 1,272,000 (CTC: JPY 9,045,000+1,638,000) \nSo maximum CTC a candidate can get after 1 year depending upon his performance is JPY 9,045,000+ 1,638,000+ 1,638,000 = 12,321,000JPY'),
#  Document(metadata={'producer': 'Microsoft: Print To PDF', 'creator': 'PyPDF', 'creationdate': '2025-09-19T19:17:00+09:00', 'author': 'AtoJ-Ruchira', 'moddate': '2025-09-19T19:17:00+09:00', 'title': 'IITçŽ»é„²çﬂ¨Job Description(2025-2026)0903æ‘’å⁄º.xlsx', 'source': '..\\data\\pdf\\AI researcher.pdf', 'total_pages': 2, 'page': 1, 'page_label': '2', 'source file': 'AI researcher.pdf', 'file_type': 'pdf'}, page_content='So maximum CTC a candidate can get after 1 year depending upon his performance is JPY 9,045,000+ 1,638,000+ 1,638,000 = 12,321,000JPY \nAllowances Commuting allowance,Meal allowance,Allowance Upon Joining(\\150,000, Flight Tickets, Moving Expense, Cost for initial VISA)\nNo overtime allowance\nHolidays Annual Paid Leaves:\u300020 days annually\nBenefits\nEmployment insurance\nWorkers’ Accident insurance           *Social insurance fee is deducted from salary.\nHealth insurance\nPension Insurance\nOfficial Working \nHours Base 8 hours / day\nPOSTGRAD\nCTC (Cost to \nCompany) 9,045,000 JPY\nCTC (breakdown)\n・Basic salary: 6,553,000 JPY \n・Allowance(Meal, Commuting, etc): 460,000 JPY\n・House Rent: 1,032,000 JPY *Guarantee fee will be deducted from salary\u3000 \n・JPN language lesson:  1,000,000 JPY\nTake Home (In Hand) 5,088,000 JPY *After tax\nGross Taxable \nIncome 6,553,000 -9,097,000JPY  *depend on Bonus\nMonthly Fixed Pay546,000 JPY （424,000 JPY *After tax）\nBonus'),
#  Document(metadata={'producer': 'Microsoft: Print To PDF', 'creator': 'PyPDF', 'creationdate': '2025-09-19T19:17:00+09:00', 'author': 'AtoJ-Ruchira', 'moddate': '2025-09-19T19:17:00+09:00', 'title': 'IITçŽ»é„²çﬂ¨Job Description(2025-2026)0903æ‘’å⁄º.xlsx', 'source': '..\\data\\pdf\\AI researcher.pdf', 'total_pages': 2, 'page': 1, 'page_label': '2', 'source file': 'AI researcher.pdf', 'file_type': 'pdf'}, page_content='Take Home (In Hand) 5,088,000 JPY *After tax\nGross Taxable \nIncome 6,553,000 -9,097,000JPY  *depend on Bonus\nMonthly Fixed Pay546,000 JPY （424,000 JPY *After tax）\nBonus\nAfter every 6 months of evaluation (CTC calculations are before tax):\n1. Output meets the assignments: no incentive (CTC: JPY 9,045,000)\n2. Outstanding outputs: additional bonus(*after tax) of JPY 636,000 (CTC: JPY 9,045,000+819,000) \n3. Supreme outputs: additional bonus(*after tax) of JPY 1,272,000 (CTC: JPY 9,045,000+1,638,000) \nSo maximum CTC a candidate can get after 1 year depending upon his performance is JPY 9,045,000+ 1,638,000+ 1,638,000 = 12,321,000JPY \nAllowances Commuting allowance,Meal allowance,Allowance Upon Joining(\\150,000, Flight Tickets, Moving Expense, Cost for initial VISA)\nNo overtime allowance\nHolidays Annual Paid Leaves:\u300020 days annually\nBenefits\nEmployment insurance\nWorkers’ Accident insurance           *Social insurance fee is deducted from salary.\nHealth insurance\nPension Insurance'),
#  Document(metadata={'producer': 'Microsoft: Print To PDF', 'creator': 'PyPDF', 'creationdate': '2025-09-19T19:17:00+09:00', 'author': 'AtoJ-Ruchira', 'moddate': '2025-09-19T19:17:00+09:00', 'title': 'IITçŽ»é„²çﬂ¨Job Description(2025-2026)0903æ‘’å⁄º.xlsx', 'source': '..\\data\\pdf\\AI researcher.pdf', 'total_pages': 2, 'page': 1, 'page_label': '2', 'source file': 'AI researcher.pdf', 'file_type': 'pdf'}, page_content='Holidays Annual Paid Leaves:\u300020 days annually\nBenefits\nEmployment insurance\nWorkers’ Accident insurance           *Social insurance fee is deducted from salary.\nHealth insurance\nPension Insurance\nOfficial Working \nHours Base 8 hours / day'),
#  Document(metadata={'producer': 'macOS Version 15.7.1 (Build 24G231) Quartz PDFContext', 'creator': 'Pages', 'creationdate': "D:20251104070722Z00'00'", 'title': 'JD-Machine Learning Engineer', 'moddate': "D:20251104070722Z00'00'", 'source': '..\\data\\pdf\\apple_jd.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1', 'source file': 'apple_jd.pdf', 'file_type': 'pdf'}, page_content='Machine Learning Engineer \nLocation: Bangalore\nJob Description \nAre you interested in applying your quantitative skills in a fast paced tech environment? \nIf so, then this is the job for you. The Worldwide Sales and Operations Advanced \nAnalytics team is looking for an experienced Machine Learning Scientist with a deep \npassion for analytical solutions that have direct and measurable impact to Apple and its \ncustomers. You will design, build and deploy predictive and prescriptive end-to-end \nsolutions for strategic and tactical supply chain decision-making.\nYou will be part of a team of experts responsible for delivering data analytics and AI/ML/\nGenAI Solutions at scale to the organization. You will be working closely with business \nstakeholders, other data scientists, and IT groups in incorporating the essential tradeoffs \nwithin the models and take an active role in effectively communicating the \nrecommendations to senior management. This is an exciting opportunity to understand'),
#  Document(metadata={'producer': 'macOS Version 15.7.1 (Build 24G231) Quartz PDFContext', 'creator': 'Pages', 'creationdate': "D:20251104070722Z00'00'", 'title': 'JD-Machine Learning Engineer', 'moddate': "D:20251104070722Z00'00'", 'source': '..\\data\\pdf\\apple_jd.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1', 'source file': 'apple_jd.pdf', 'file_type': 'pdf'}, page_content='within the models and take an active role in effectively communicating the \nrecommendations to senior management. This is an exciting opportunity to understand \nApple’s Supply Chain dynamics and apply your quantitative and analytical skills to \ninﬂuence data-driven decisions at scale.\nThe role involves building applications harnessing large amounts of data across all of \nApple’s products, leveraging AI/ML and large language models.\nQUALIFICATIONS\n• Desire to solve real-world problems and a strong understanding of machine learning \nconcepts.\n• Ability to implement data science pipelines and applications in a general \nprogramming language such as Python, Scala, Java or C++\n• Hands on knowledge with database modeling, data warehousing principles and SQL\n• Ability to comprehend and debug complex systems integrations spanning tools and \nteams. Strong critical thinking and problem solving ability\n• Sound communication skills - adept at messaging domain and technical content, at a'),
#  Document(metadata={'producer': 'macOS Version 15.7.1 (Build 24G231) Quartz PDFContext', 'creator': 'Pages', 'creationdate': "D:20251104070722Z00'00'", 'title': 'JD-Machine Learning Engineer', 'moddate': "D:20251104070722Z00'00'", 'source': '..\\data\\pdf\\apple_jd.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1', 'source file': 'apple_jd.pdf', 'file_type': 'pdf'}, page_content='teams. Strong critical thinking and problem solving ability\n• Sound communication skills - adept at messaging domain and technical content, at a \nlevel appropriate for the audience.\n• Experienced at understanding key performance levers and metrics to highlight \noperational issues and drive improvement\n• Innate curiosity and bias to action with expert ability to identify, deﬁne and execute \nproject plans and develop modeling approaches suitable for the problem\n• Strong team player - invested in the collective success of the team and project \noutcomes\n• Self-sufﬁcient with an ability to thrive in an environment of autonomy amidst ambiguity\nEDUCATION\n• Masters/Dual Degree in Department of Data Science and AI, Computer Science, \nInformation Science (with focus on AI/ML, GenAI and Analytics)'),
#  Document(metadata={'producer': 'Microsoft: Print To PDF', 'creator': 'PyPDF', 'creationdate': '2025-09-19T19:15:31+09:00', 'author': 'AtoJ-Ruchira', 'moddate': '2025-09-19T19:15:31+09:00', 'title': 'IITçŽ»é„²çﬂ¨Job Description(2025-2026)0903æ‘’å⁄º.xlsx', 'source': '..\\data\\pdf\\Applied Data Scientist.pdf', 'total_pages': 2, 'page': 0, 'page_label': '1', 'source file': 'Applied Data Scientist.pdf', 'file_type': 'pdf'}, page_content='Honda Motor Co., \nLtd.\nSkills\n【Required Experience and Skills】\nApplicants should possess experience and strong foundation in modern Data Science\n【Preferred Experience and Skills】\nIn addition to the above, the following experience and skills are desirable:\n- Experience in deriving value through data science and mathematical modeling.\n- Experience in spatiotemporal analysis of probe data and sensing data.\n- Knowledge or development experience related to autonomous driving and advanced driver-assistance systems (ADAS).\n- English communication skills.\n- Experience in project management, etc.\n【Ideal Candidate Profile】\nWe are looking for individuals who:\n- Are highly motivated to contribute to Honda’s AD/ADAS development and new business domains such as recurring revenue through data analysis.\n- Are eager to respond quickly to customer and market needs, and continuously improve operations and products with an agile mindset.'),
#  Document(metadata={'producer': 'Microsoft: Print To PDF', 'creator': 'PyPDF', 'creationdate': '2025-09-19T19:15:31+09:00', 'author': 'AtoJ-Ruchira', 'moddate': '2025-09-19T19:15:31+09:00', 'title': 'IITçŽ»é„²çﬂ¨Job Description(2025-2026)0903æ‘’å⁄º.xlsx', 'source': '..\\data\\pdf\\Applied Data Scientist.pdf', 'total_pages': 2, 'page': 0, 'page_label': '1', 'source file': 'Applied Data Scientist.pdf', 'file_type': 'pdf'}, page_content='- Are eager to respond quickly to customer and market needs, and continuously improve operations and products with an agile mindset.\n- Proactively engage and collaborate with internal and external stakeholders.\nApplied Data Scientist\nJob Description\nHonda is a total mobility company dedicated to delivering the "joy of free movement." We innovate in various fields, including motorcycles, automobiles, \npower products, aircraft and aircraft engines, and robotics. Honda operates in markets across about 200 countries worldwide, continuously creating next-\ngeneration mobility solutions and products that improve people’s lives by combining our technology and expertise.\nAt Honda, everyone, regardless of nationality, gender, educational background, or experience, can freely express their ideas. Since our founding, we have \nmaintained the ambition of asking, "What can we do for the world and for people?"'),
#  Document(metadata={'producer': 'Microsoft: Print To PDF', 'creator': 'PyPDF', 'creationdate': '2025-09-19T19:15:31+09:00', 'author': 'AtoJ-Ruchira', 'moddate': '2025-09-19T19:15:31+09:00', 'title': 'IITçŽ»é„²çﬂ¨Job Description(2025-2026)0903æ‘’å⁄º.xlsx', 'source': '..\\data\\pdf\\Applied Data Scientist.pdf', 'total_pages': 2, 'page': 0, 'page_label': '1', 'source file': 'Applied Data Scientist.pdf', 'file_type': 'pdf'}, page_content='maintained the ambition of asking, "What can we do for the world and for people?"\nWe believe that having dreams and staying passionate about making them a reality is the reason Honda exists. "It\'s not about what happens; it\'s about what \nyou do." You are the ones who will shape the future of the world. As you move forward in life, we hope you will be the main character in the moments when \nthe world changes.\nIf you have a desire to achieve something, to create something, or to make your dreams come true, why not realize those aspirations at Honda?\n〈Software Defined Mobility Development Supervisory Unit, Advanced Safety and Intelligent Solution Development Division〉\nOur mission is to develop world-leading safety features and autonomous driving systems, and to deliver the safest vehicles in the world. Honda\'s AD/ADAS \nData Platform Group provides an ecosystem for AD/ADAS system development to analyze and test safety and functionality through simulations, insight and'),
#  Document(metadata={'producer': 'Microsoft: Print To PDF', 'creator': 'PyPDF', 'creationdate': '2025-09-19T19:15:31+09:00', 'author': 'AtoJ-Ruchira', 'moddate': '2025-09-19T19:15:31+09:00', 'title': 'IITçŽ»é„²çﬂ¨Job Description(2025-2026)0903æ‘’å⁄º.xlsx', 'source': '..\\data\\pdf\\Applied Data Scientist.pdf', 'total_pages': 2, 'page': 0, 'page_label': '1', 'source file': 'Applied Data Scientist.pdf', 'file_type': 'pdf'}, page_content='Data Platform Group provides an ecosystem for AD/ADAS system development to analyze and test safety and functionality through simulations, insight and \nanalysis of sensing data from test vehicles. The ecosystem is used in the critical process of validating the results of functional development and obtaining \n“type certification”. \nIn this division, the engineers who developed the world’s first Level 3 automated driving system are continuously researching and commercializing cutting-\nedge technologies. Through the development of Level 3 autonomous driving systems, Honda has gained access to valuable market data from both customer \nand test vehicles. This data is utilized to improve safety validation, product planning, and functional design. The results of your analysis will be applied \nglobally through Honda’s extensive international network, contributing to the realization of a society with zero traffic fatalities.'),
#  Document(metadata={'producer': 'Microsoft: Print To PDF', 'creator': 'PyPDF', 'creationdate': '2025-09-19T19:15:31+09:00', 'author': 'AtoJ-Ruchira', 'moddate': '2025-09-19T19:15:31+09:00', 'title': 'IITçŽ»é„²çﬂ¨Job Description(2025-2026)0903æ‘’å⁄º.xlsx', 'source': '..\\data\\pdf\\Applied Data Scientist.pdf', 'total_pages': 2, 'page': 0, 'page_label': '1', 'source file': 'Applied Data Scientist.pdf', 'file_type': 'pdf'}, page_content='globally through Honda’s extensive international network, contributing to the realization of a society with zero traffic fatalities.\nTo increase the number of people who smile through their experience with cars, we are seeking teammates who will lead Honda’s global four-wheel \ndevelopment—from foundational product development optimized for each region to cutting-edge technology innovation. As of July 2025, there are currently \n10 Indian engineers and 2 Chinese engineers on the team. An additional 6 engineers—all graduates of IIT (Indian Institutes of Technology)—are scheduled to \njoin in October 2025.\nEmployees who proactively engage with their work and demonstrate strong initiative are entrusted with major responsibilities, even shortly after joining. We \nwelcome individuals with the drive to raise their hand and launch projects with the spirit of “I want to create this kind of technology!”'),
#  Document(metadata={'producer': 'Microsoft: Print To PDF', 'creator': 'PyPDF', 'creationdate': '2025-09-19T19:15:31+09:00', 'author': 'AtoJ-Ruchira', 'moddate': '2025-09-19T19:15:31+09:00', 'title': 'IITçŽ»é„²çﬂ¨Job Description(2025-2026)0903æ‘’å⁄º.xlsx', 'source': '..\\data\\pdf\\Applied Data Scientist.pdf', 'total_pages': 2, 'page': 0, 'page_label': '1', 'source file': 'Applied Data Scientist.pdf', 'file_type': 'pdf'}, page_content='welcome individuals with the drive to raise their hand and launch projects with the spirit of “I want to create this kind of technology!”\nOur mission is to develop world-class safety features and autonomous driving systems to deliver the safest vehicles worldwide. By utilizing market data from \ncustomer vehicles and development vehicle data collected through Honda’s Level 3 autonomous driving system development, you will play a key role in \nsafety validation, product planning, and functional design.\n【Job Details】 \nYou will be responsible for advanced data analysis to support the next-generation development of driver assistance and autonomous driving systems:\n- Analyze real-world test data and probe data to extract insights that drive the development of autonomous driving and driver assistance technologies.\n- Implement advanced analytics and automation funcationalities, inclduing ML and Gen-AI techniques for intelligent data analysis.'),
#  Document(metadata={'producer': 'Microsoft: Print To PDF', 'creator': 'PyPDF', 'creationdate': '2025-09-19T19:15:31+09:00', 'author': 'AtoJ-Ruchira', 'moddate': '2025-09-19T19:15:31+09:00', 'title': 'IITçŽ»é„²çﬂ¨Job Description(2025-2026)0903æ‘’å⁄º.xlsx', 'source': '..\\data\\pdf\\Applied Data Scientist.pdf', 'total_pages': 2, 'page': 0, 'page_label': '1', 'source file': 'Applied Data Scientist.pdf', 'file_type': 'pdf'}, page_content='- Implement advanced analytics and automation funcationalities, inclduing ML and Gen-AI techniques for intelligent data analysis.\n- Analyze simulation data to support MILS development operations and the development of AD/ADAS models.\nYou will collaborate with a wide range of stakeholders, including internal departments and external vendors. There may also be opportunities to work with \noverseas teams, such as conducting demonstrations for local subsidiaries or engaging in joint research with international institutions. Specific tasks will be \nassigned based on your experience and skills. Depending on your expertise, aptitude, and company requirements, you may be reassigned to other duties as \ndefined by the company.\n【Development Tools】\nLanguages: R, Python, SQL\nData Analysis / AI Libraries: numpy, scipy, scikit-learn, Jupyter Notebook, PyTorch\nGen-AI: VLM/LLM, RAG pipelines, Agentic Frameworks (LangChain, CrewAI). Protocols (MCP)\nSimulation Tools: Matlab/Simulink, CarMaker, Carla'),
#  Document(metadata={'producer': 'Microsoft: Print To PDF', 'creator': 'PyPDF', 'creationdate': '2025-09-19T19:15:31+09:00', 'author': 'AtoJ-Ruchira', 'moddate': '2025-09-19T19:15:31+09:00', 'title': 'IITçŽ»é„²çﬂ¨Job Description(2025-2026)0903æ‘’å⁄º.xlsx', 'source': '..\\data\\pdf\\Applied Data Scientist.pdf', 'total_pages': 2, 'page': 0, 'page_label': '1', 'source file': 'Applied Data Scientist.pdf', 'file_type': 'pdf'}, page_content='Gen-AI: VLM/LLM, RAG pipelines, Agentic Frameworks (LangChain, CrewAI). Protocols (MCP)\nSimulation Tools: Matlab/Simulink, CarMaker, Carla\nCloud: AWS(Amazon SageMaker, Amazon Athena, Amazon Redshift), GCP, Azure\nCI/CD: Git, Docker\nCRM Tools & Integration: Salesforce, Sentiment analysis, Predictive analysis'),
#  Document(metadata={'producer': 'Microsoft: Print To PDF', 'creator': 'PyPDF', 'creationdate': '2025-09-19T19:15:31+09:00', 'author': 'AtoJ-Ruchira', 'moddate': '2025-09-19T19:15:31+09:00', 'title': 'IITçŽ»é„²çﬂ¨Job Description(2025-2026)0903æ‘’å⁄º.xlsx', 'source': '..\\data\\pdf\\Applied Data Scientist.pdf', 'total_pages': 2, 'page': 1, 'page_label': '2', 'source file': 'Applied Data Scientist.pdf', 'file_type': 'pdf'}, page_content='UNDERGRAD\nCTC (Cost to \nCompany)\nCTC (breakdown)\nTake Home (In Hand)\nGross Taxable \nIncome\nMonthly Fixed Pay\nBonus\nAllowances\nHolidays\nBenefits\nOfficial Working \nHours\nPOSTGRAD\nCTC (Cost to \nCompany)\nCTC (breakdown)\nTake Home (In Hand)\nGross Taxable \nIncome\nMonthly Fixed Pay\nBonus\nAllowances\nHolidays\nBenefits\nOfficial Working \nHours\nAfter every 6 months of evaluation:  (CTC calculations are before tax):\n1. Output meets the assignments: no incentive (CTC: JPY 8,757,000) \n2. Outstanding outputs: additional bonus(*after tax) of JPY 636,000 (CTC: JPY 8,757,000+819,000) \n3. Supreme outputs: additional bonus(*after tax) of JPY 1,272,000 (CTC: JPY 8,757,000+1,638,000) \nSo maximum CTC a candidate can get after 1 year depending upon his performance is JPY 8,757,000+ 1,638,000+ 1,638,000 =12,033,000JPY\nCommuting allowance,Meal allowance,Allowance Upon Joining\n(\\150,000, Flight Tickets, Moving Expense, Cost for initial VISA)\nNo overtime allowance\nAnnual Paid Leaves:\u300020 days annually'),
#  Document(metadata={'producer': 'Microsoft: Print To PDF', 'creator': 'PyPDF', 'creationdate': '2025-09-19T19:15:31+09:00', 'author': 'AtoJ-Ruchira', 'moddate': '2025-09-19T19:15:31+09:00', 'title': 'IITçŽ»é„²çﬂ¨Job Description(2025-2026)0903æ‘’å⁄º.xlsx', 'source': '..\\data\\pdf\\Applied Data Scientist.pdf', 'total_pages': 2, 'page': 1, 'page_label': '2', 'source file': 'Applied Data Scientist.pdf', 'file_type': 'pdf'}, page_content='Commuting allowance,Meal allowance,Allowance Upon Joining\n(\\150,000, Flight Tickets, Moving Expense, Cost for initial VISA)\nNo overtime allowance\nAnnual Paid Leaves:\u300020 days annually\nEmployment insurance\nWorkers’ Accident insurance           *Social insurance fee is deducted from salary.\nHealth insurance\nPension Insurance\nBase 8 hours / day\n8,757,000 JPY\n・Basic salary: 6,553,000 JPY \n5,088,000 JPY *After tax\n6,553,000 -9,097,000JPY  *depend on Bonus\n546,000 JPY （424,000 JPY *After tax）\n546,000 JPY （424,000 JPY *After tax）\nAfter every 6 months of evaluation:  (CTC calculations are before tax):\n1. Output meets the assignments: no incentive (CTC: JPY 8,757,000) \n2. Outstanding outputs: additional bonus(*after tax) of JPY 636,000 (CTC: JPY 8,757,000+819,000) \n3. Supreme outputs: additional bonus(*after tax) of JPY 1,272,000 (CTC: JPY 8,757,000+1,638,000) \nSo maximum CTC a candidate can get after 1 year depending upon his performance is JPY 8,757,000+ 1,638,000+ 1,638,000 =12,033,000JPY'),
#  Document(metadata={'producer': 'Microsoft: Print To PDF', 'creator': 'PyPDF', 'creationdate': '2025-09-19T19:15:31+09:00', 'author': 'AtoJ-Ruchira', 'moddate': '2025-09-19T19:15:31+09:00', 'title': 'IITçŽ»é„²çﬂ¨Job Description(2025-2026)0903æ‘’å⁄º.xlsx', 'source': '..\\data\\pdf\\Applied Data Scientist.pdf', 'total_pages': 2, 'page': 1, 'page_label': '2', 'source file': 'Applied Data Scientist.pdf', 'file_type': 'pdf'}, page_content='So maximum CTC a candidate can get after 1 year depending upon his performance is JPY 8,757,000+ 1,638,000+ 1,638,000 =12,033,000JPY\nCommuting allowance,Meal allowance,Allowance Upon Joining(\\150,000, Flight Tickets, Moving Expense, Cost for initial VISA)\nNo overtime allowance\nAnnual Paid Leaves:\u300020 days annually\nEmployment insurance\nWorkers’ Accident insurance           *Social insurance fee is deducted from salary.\nHealth insurance\nPension Insurance\nBase 8 hours / day\n8,757,000 JPY\n・Basic salary: 6,553,000 JPY \n・Allowance(Meal, Commuting, etc): 460,000 JPY\n・House Rent: 744,000 JPY\u3000 *Guarantee fee will be deducted from salary\u3000 \n・JPN language lesson:  1,000,000 JPYE75\n5,088,000 JPY *After tax\n6,553,000 -9,097,000JPY  *depend on Bonus'),
#  Document(metadata={'producer': 'Microsoft: Print To PDF', 'creator': 'PyPDF', 'creationdate': '2025-09-19T19:16:02+09:00', 'author': 'AtoJ-Ruchira', 'moddate': '2025-09-19T19:16:02+09:00', 'title': 'IITçŽ»é„²çﬂ¨Job Description(2025-2026)0903æ‘’å⁄º.xlsx', 'source': '..\\data\\pdf\\Data Engineer.pdf', 'total_pages': 2, 'page': 0, 'page_label': '1', 'source file': 'Data Engineer.pdf', 'file_type': 'pdf'}, page_content='Honda Motor Co., \nLtd. Data Engineer\nHonda is a total mobility company dedicated to delivering the "joy of free movement." We innovate in various fields, including motorcycles, automobiles, power products, aircraft \nand aircraft engines, and robotics. Honda operates in markets across about 200 countries worldwide, continuously creating next-generation mobility solutions and products that \nimprove people’s lives by combining our technology and expertise.\nAt Honda, everyone, regardless of nationality, gender, educational background, or experience, can freely express their ideas. Since our founding, we have maintained the ambition of \nasking, "What can we do for the world and for people?"\nWe believe that having dreams and staying passionate about making them a reality is the reason Honda exists. "It\'s not about what happens; it\'s about what you do." You are the'),
#  Document(metadata={'producer': 'Microsoft: Print To PDF', 'creator': 'PyPDF', 'creationdate': '2025-09-19T19:16:02+09:00', 'author': 'AtoJ-Ruchira', 'moddate': '2025-09-19T19:16:02+09:00', 'title': 'IITçŽ»é„²çﬂ¨Job Description(2025-2026)0903æ‘’å⁄º.xlsx', 'source': '..\\data\\pdf\\Data Engineer.pdf', 'total_pages': 2, 'page': 0, 'page_label': '1', 'source file': 'Data Engineer.pdf', 'file_type': 'pdf'}, page_content='We believe that having dreams and staying passionate about making them a reality is the reason Honda exists. "It\'s not about what happens; it\'s about what you do." You are the \nones who will shape the future of the world. As you move forward in life, we hope you will be the main character in the moments when the world changes.\nIf you have a desire to achieve something, to create something, or to make your dreams come true, why not realize those aspirations at Honda?\n〈Software Defined Mobility Development Supervisory Unit, Advanced Safety and Intelligent Solution Development Division〉\nOur mission is to develop world-leading safety features and autonomous driving systems, and to deliver the safest vehicles in the world. Honda\'s AD/ADAS Data Platform Group \nprovides an ecosystem for AD/ADAS system development to analyze and test safety and functionality through simulations, insight and analysis of sensing data from test vehicles. The'),
#  Document(metadata={'producer': 'Microsoft: Print To PDF', 'creator': 'PyPDF', 'creationdate': '2025-09-19T19:16:02+09:00', 'author': 'AtoJ-Ruchira', 'moddate': '2025-09-19T19:16:02+09:00', 'title': 'IITçŽ»é„²çﬂ¨Job Description(2025-2026)0903æ‘’å⁄º.xlsx', 'source': '..\\data\\pdf\\Data Engineer.pdf', 'total_pages': 2, 'page': 0, 'page_label': '1', 'source file': 'Data Engineer.pdf', 'file_type': 'pdf'}, page_content='provides an ecosystem for AD/ADAS system development to analyze and test safety and functionality through simulations, insight and analysis of sensing data from test vehicles. The \necosystem is used in the critical process of validating the results of functional development and obtaining “type certification”. \nIn this division, the engineers who developed the world’s first Level 3 automated driving system are continuously researching and commercializing cutting-edge technologies. \nThrough the development of Level 3 autonomous driving systems, Honda has gained access to valuable market data from both customer and test vehicles. This data is utilized to \nimprove safety validation, product planning, and functional design. The results of your analysis will be applied globally through Honda’s extensive international network, contributing \nto the realization of a society with zero traffic fatalities.'),
#  Document(metadata={'producer': 'Microsoft: Print To PDF', 'creator': 'PyPDF', 'creationdate': '2025-09-19T19:16:02+09:00', 'author': 'AtoJ-Ruchira', 'moddate': '2025-09-19T19:16:02+09:00', 'title': 'IITçŽ»é„²çﬂ¨Job Description(2025-2026)0903æ‘’å⁄º.xlsx', 'source': '..\\data\\pdf\\Data Engineer.pdf', 'total_pages': 2, 'page': 0, 'page_label': '1', 'source file': 'Data Engineer.pdf', 'file_type': 'pdf'}, page_content='to the realization of a society with zero traffic fatalities.\nTo increase the number of people who smile through their experience with cars, we are seeking teammates who will lead Honda’s global four-wheel development—from \nfoundational product development optimized for each region to cutting-edge technology innovation. As of July 2025, there are currently 10 Indian engineers and 2 Chinese engineers \non the team. An additional 6 engineers—all graduates of IIT (Indian Institutes of Technology)—are scheduled to join in October 2025.\nEmployees who proactively engage with their work and demonstrate strong initiative are entrusted with major responsibilities, even shortly after joining. We welcome individuals \nwith the drive to raise their hand and launch projects with the spirit of “I want to create this kind of technology!”\n <Responsibilities> \n- Learn and understand existing workflows and system configurations for model-in-the-loop (MIL) simulation, data analysis, and testing.'),
#  Document(metadata={'producer': 'Microsoft: Print To PDF', 'creator': 'PyPDF', 'creationdate': '2025-09-19T19:16:02+09:00', 'author': 'AtoJ-Ruchira', 'moddate': '2025-09-19T19:16:02+09:00', 'title': 'IITçŽ»é„²çﬂ¨Job Description(2025-2026)0903æ‘’å⁄º.xlsx', 'source': '..\\data\\pdf\\Data Engineer.pdf', 'total_pages': 2, 'page': 0, 'page_label': '1', 'source file': 'Data Engineer.pdf', 'file_type': 'pdf'}, page_content='<Responsibilities> \n- Learn and understand existing workflows and system configurations for model-in-the-loop (MIL) simulation, data analysis, and testing.\n- Continuously propose improvements to data analysis methods and approaches for better summarization and insight generation.\n- Develop analysis and ETL/ELT pipelines following industry-standard practices.\n- Create self-contained solutions that can be built and deployed in a fully automated manner.\n- Collaborate with other data engineers to build improved pipelines and high-visibility dashboards for the entire AD/ADAS development team, contributing to Honda’s data \necosystem.\n \n<Specific Goals> \n[1st -2nd year] \n- Understand existing analysis approach and workflows and propose solutions.\n- Accomplish PoC of data analysis and ecosystem improvement to get rapid development practice in AD/ADAS development team.'),
#  Document(metadata={'producer': 'Microsoft: Print To PDF', 'creator': 'PyPDF', 'creationdate': '2025-09-19T19:16:02+09:00', 'author': 'AtoJ-Ruchira', 'moddate': '2025-09-19T19:16:02+09:00', 'title': 'IITçŽ»é„²çﬂ¨Job Description(2025-2026)0903æ‘’å⁄º.xlsx', 'source': '..\\data\\pdf\\Data Engineer.pdf', 'total_pages': 2, 'page': 0, 'page_label': '1', 'source file': 'Data Engineer.pdf', 'file_type': 'pdf'}, page_content='- Understand existing analysis approach and workflows and propose solutions.\n- Accomplish PoC of data analysis and ecosystem improvement to get rapid development practice in AD/ADAS development team.\n- Accomplish improved analysis workflow and create an effective way to share multiple type of data and test result among stake-holders in the ecosystem.\n[3rd -5th year] \nThe successful candidate will generalize his/her analysis method for wider areas, and demonstrate it on in-house system and provide to all-Honda members for data ecosystem. \nThe successful candidate must have the ability to meet tight deadlines, have strong interpersonal and communication skills, be detail oriented, and have the ability to work \nindependently and be a self-starter.\n【Preferred Experience and Skills】\nCandidates should possess knowledge or experience in one or more of the following areas:\n- Skills in building dashboards (e.g., Qlik Sense, B-dash, Streamlit, etc.).'),
#  Document(metadata={'producer': 'Microsoft: Print To PDF', 'creator': 'PyPDF', 'creationdate': '2025-09-19T19:16:02+09:00', 'author': 'AtoJ-Ruchira', 'moddate': '2025-09-19T19:16:02+09:00', 'title': 'IITçŽ»é„²çﬂ¨Job Description(2025-2026)0903æ‘’å⁄º.xlsx', 'source': '..\\data\\pdf\\Data Engineer.pdf', 'total_pages': 2, 'page': 0, 'page_label': '1', 'source file': 'Data Engineer.pdf', 'file_type': 'pdf'}, page_content='【Preferred Experience and Skills】\nCandidates should possess knowledge or experience in one or more of the following areas:\n- Skills in building dashboards (e.g., Qlik Sense, B-dash, Streamlit, etc.).\n- Excellent software architecture design skills (must be familiar with Python).\n- DevOps skills (CI/CD, build processes, infrastructure deployment).\n- Knowledge of data management middleware such as databases, data lakes, query engines, etc.\n- Monitoring skills (e.g., error notifications via email or chat).\n- Experience working in cloud environments.\n- Fundamental knowledge of Generative AI.\nIn addition to the above, having the following traits and skills would be a plus:\n- Contribution to Open Source Software Communities.\n- Understanding of international cultural studies, including Japanese culture.\n- Any exposure to or proficiency in the Japanese language is welcome.\n【Ideal Candidate Profile】\nWe are looking for individuals who possess the following mindset and aptitudes:'),
#  Document(metadata={'producer': 'Microsoft: Print To PDF', 'creator': 'PyPDF', 'creationdate': '2025-09-19T19:16:02+09:00', 'author': 'AtoJ-Ruchira', 'moddate': '2025-09-19T19:16:02+09:00', 'title': 'IITçŽ»é„²çﬂ¨Job Description(2025-2026)0903æ‘’å⁄º.xlsx', 'source': '..\\data\\pdf\\Data Engineer.pdf', 'total_pages': 2, 'page': 0, 'page_label': '1', 'source file': 'Data Engineer.pdf', 'file_type': 'pdf'}, page_content='- Any exposure to or proficiency in the Japanese language is welcome.\n【Ideal Candidate Profile】\nWe are looking for individuals who possess the following mindset and aptitudes:\n- Strong motivation to contribute to Honda’s AD/ADAS development and emerging domains such as recurring business through data and cloud technologies.\n- Willingness to quickly respond to customer and market needs, and proactively update operations and products with an agile mindset.\n- Ability to actively engage and collaborate with people both inside and outside the organization\nSkills\nJob Description'),
#  Document(metadata={'producer': 'Microsoft: Print To PDF', 'creator': 'PyPDF', 'creationdate': '2025-09-19T19:16:02+09:00', 'author': 'AtoJ-Ruchira', 'moddate': '2025-09-19T19:16:02+09:00', 'title': 'IITçŽ»é„²çﬂ¨Job Description(2025-2026)0903æ‘’å⁄º.xlsx', 'source': '..\\data\\pdf\\Data Engineer.pdf', 'total_pages': 2, 'page': 1, 'page_label': '2', 'source file': 'Data Engineer.pdf', 'file_type': 'pdf'}, page_content='UNDERGRAD\nCTC (Cost to \nCompany) 8,757,000 JPY\nCTC (breakdown)\n・Basic salary: 6,553,000 JPY \n・Allowance(Meal, Commuting, etc): 460,000 JPY\n・House Rent: 744,000 JPY\u3000 *Guarantee fee will be deducted from salary\u3000 \n・JPN language lesson:  1,000,000 JPY\nTake Home (In Hand) 5,088,000 JPY *After tax\nGross Taxable \nIncome 6,553,000 -9,097,000JPY  *depend on Bonus\nMonthly Fixed Pay546,000 JPY （424,000 JPY *After tax）\nBonus\nAfter every 6 months of evaluation:  (CTC calculations are before tax):\n1. Output meets the assignments: no incentive (CTC: JPY 8,757,000) \n2. Outstanding outputs: additional bonus(*after tax) of JPY 636,000 (CTC: JPY 8,757,000+819,000) \n3. Supreme outputs: additional bonus(*after tax) of JPY 1,272,000 (CTC: JPY 8,757,000+1,638,000) \nSo maximum CTC a candidate can get after 1 year depending upon his performance is JPY 8,757,000+ 1,638,000+ 1,638,000 =12,033,000JPY'),
# ...
#  Document(metadata={'producer': 'Microsoft: Print To PDF', 'creator': 'PyPDF', 'creationdate': '2025-09-19T19:16:02+09:00', 'author': 'AtoJ-Ruchira', 'moddate': '2025-09-19T19:16:02+09:00', 'title': 'IITçŽ»é„²çﬂ¨Job Description(2025-2026)0903æ‘’å⁄º.xlsx', 'source': '..\\data\\pdf\\Data Engineer.pdf', 'total_pages': 2, 'page': 1, 'page_label': '2', 'source file': 'Data Engineer.pdf', 'file_type': 'pdf'}, page_content='Holidays Annual Paid Leaves:\u300020 days annually\nBenefits\nEmployment insurance\nWorkers’ Accident insurance           *Social insurance fee is deducted from salary.\nHealth insurance\nPension Insurance\nOfficial Working \nHours Base 8 hours / day'),
#  Document(metadata={'producer': 'Microsoft: Print To PDF', 'creator': 'PyPDF', 'creationdate': '2025-09-19T19:16:30+09:00', 'author': 'AtoJ-Ruchira', 'moddate': '2025-09-19T19:16:30+09:00', 'title': 'IITçŽ»é„²çﬂ¨Job Description(2025-2026)0903æ‘’å⁄º.xlsx', 'source': '..\\data\\pdf\\DNN Developer.pdf', 'total_pages': 2, 'page': 0, 'page_label': '1', 'source file': 'DNN Developer.pdf', 'file_type': 'pdf'}, page_content='Honda Motor Co., \nLtd. Deep Neural Network (DNN) Development Engineer\nHonda is a total mobility company dedicated to delivering the "joy of free movement." We innovate in various fields, including motorcycles, automobiles, power products, aircraft \nand aircraft engines, and robotics. Honda operates in markets across about 200 countries worldwide, continuously creating next-generation mobility solutions and products that \nimprove people’s lives by combining our technology and expertise.\nAt Honda, everyone, regardless of nationality, gender, educational background, or experience, can freely express their ideas. Since our founding, we have maintained the ambition of \nasking, "What can we do for the world and for people?"\nWe believe that having dreams and staying passionate about making them a reality is the reason Honda exists. "It\'s not about what happens; it\'s about what you do." You are the'),
#  Document(metadata={'producer': 'Microsoft: Print To PDF', 'creator': 'PyPDF', 'creationdate': '2025-09-19T19:16:30+09:00', 'author': 'AtoJ-Ruchira', 'moddate': '2025-09-19T19:16:30+09:00', 'title': 'IITçŽ»é„²çﬂ¨Job Description(2025-2026)0903æ‘’å⁄º.xlsx', 'source': '..\\data\\pdf\\DNN Developer.pdf', 'total_pages': 2, 'page': 0, 'page_label': '1', 'source file': 'DNN Developer.pdf', 'file_type': 'pdf'}, page_content='We believe that having dreams and staying passionate about making them a reality is the reason Honda exists. "It\'s not about what happens; it\'s about what you do." You are the \nones who will shape the future of the world. As you move forward in life, we hope you will be the main character in the moments when the world changes.\nIf you have a desire to achieve something, to create something, or to make your dreams come true, why not realize those aspirations at Honda?\n〈Software Defined Mobility Development Supervisory Unit, Advanced Safety and Intelligent Solution Development Division〉\nHonda\'s Software Defined Mobility Development Supervisory Unit is committed to pursuing innovative development and creation of “value” in mobility and life. We aim for “Zero \ntraffic collision fatalities” involving Honda motorcycles or automobiles worldwide in 2050. The AD/ADAS division is responsible for the development of safety functions such as Honda'),
#  Document(metadata={'producer': 'Microsoft: Print To PDF', 'creator': 'PyPDF', 'creationdate': '2025-09-19T19:16:30+09:00', 'author': 'AtoJ-Ruchira', 'moddate': '2025-09-19T19:16:30+09:00', 'title': 'IITçŽ»é„²çﬂ¨Job Description(2025-2026)0903æ‘’å⁄º.xlsx', 'source': '..\\data\\pdf\\DNN Developer.pdf', 'total_pages': 2, 'page': 0, 'page_label': '1', 'source file': 'DNN Developer.pdf', 'file_type': 'pdf'}, page_content="traffic collision fatalities” involving Honda motorcycles or automobiles worldwide in 2050. The AD/ADAS division is responsible for the development of safety functions such as Honda \nSensing Elite and Honda sensing 360 for this purpose. In this division, the engineers who realized the world's first LV3 automated driving system are constantly researching and \ncommercializing the latest technologies.\nOur mission is to develop world-leading safety features and autonomous driving systems and to deliver the safest vehicles in the world. This represents a significant shift from \nconventional automobiles and demands innovation, particularly through the application of AI technologies. It is a field that requires deep technical exploration and a spirit of \nchallenge.\nWe offer an environment where you can engage in global research and development in collaboration with Honda’s overseas offices, universities, and companies. We are looking for"),
#  Document(metadata={'producer': 'Microsoft: Print To PDF', 'creator': 'PyPDF', 'creationdate': '2025-09-19T19:16:30+09:00', 'author': 'AtoJ-Ruchira', 'moddate': '2025-09-19T19:16:30+09:00', 'title': 'IITçŽ»é„²çﬂ¨Job Description(2025-2026)0903æ‘’å⁄º.xlsx', 'source': '..\\data\\pdf\\DNN Developer.pdf', 'total_pages': 2, 'page': 0, 'page_label': '1', 'source file': 'DNN Developer.pdf', 'file_type': 'pdf'}, page_content='challenge.\nWe offer an environment where you can engage in global research and development in collaboration with Honda’s overseas offices, universities, and companies. We are looking for \nteammates who possess specialized technologies that contribute to major transformations and innovations in mobility—and who are eager not only to conduct research but also to \nbring their work into the real world and make a meaningful contribution to society.\nYou will be responsible for developing one or more of the following technologies related to next-generation development of driver assistance and autonomous driving systems:\n- Image recognition algorithms and machine learning models for object and lane recognition\n- Traffic environment understanding algorithms and machine learning models using recognition data\n- Behavior planning algorithms and machine learning models based on traffic conditions\n- Edge device deployment of machine learning models'),
#  Document(metadata={'producer': 'Microsoft: Print To PDF', 'creator': 'PyPDF', 'creationdate': '2025-09-19T19:16:30+09:00', 'author': 'AtoJ-Ruchira', 'moddate': '2025-09-19T19:16:30+09:00', 'title': 'IITçŽ»é„²çﬂ¨Job Description(2025-2026)0903æ‘’å⁄º.xlsx', 'source': '..\\data\\pdf\\DNN Developer.pdf', 'total_pages': 2, 'page': 0, 'page_label': '1', 'source file': 'DNN Developer.pdf', 'file_type': 'pdf'}, page_content='- Behavior planning algorithms and machine learning models based on traffic conditions\n- Edge device deployment of machine learning models \n- Multimodal fusion technologies using cameras and other external sensing devices\n- Driver state and in-cabin recognition using DNNs and LLMs\n- Self-localization and automated map generation \n- MLOps environment construction\n- Optimization, probabilistic inference, and data mining\nYou will also be involved in R&D of AI-based functions for autonomous vehicles, as well as promoting joint research and development with universities and domestic/overseas \ncompanies.\nYou will collaborate with various stakeholders, including other departments and vendors. There may also be opportunities to engage with overseas entities, such as demonstrations \nfor local subsidiaries and joint research with international institutions.\n*Depending on your expertise, aptitude, and company needs, you may be reassigned to other duties as defined by the company.\nRequired Skills'),
#  Document(metadata={'producer': 'Microsoft: Print To PDF', 'creator': 'PyPDF', 'creationdate': '2025-09-19T19:16:30+09:00', 'author': 'AtoJ-Ruchira', 'moddate': '2025-09-19T19:16:30+09:00', 'title': 'IITçŽ»é„²çﬂ¨Job Description(2025-2026)0903æ‘’å⁄º.xlsx', 'source': '..\\data\\pdf\\DNN Developer.pdf', 'total_pages': 2, 'page': 0, 'page_label': '1', 'source file': 'DNN Developer.pdf', 'file_type': 'pdf'}, page_content='*Depending on your expertise, aptitude, and company needs, you may be reassigned to other duties as defined by the company.\nRequired Skills\nApplicants should possess one or more of the following knowledge or experience:\n- Image processing / Image recognition technology development\n- Recognition technology development using RADAR or LiDAR\n- Generative AI\n- Development using large language models (LLMs)\n- Natural Language Processing (NLP)\n- Data preprocessing\nPreferred Skills\nApplicants should possess basic knowledge or practical experience in one or more of the following:\n- Foundational AI technologies such as machine learning and deep learning\n- AI-related tools (e.g., Caffe, Chainer, TensorFlow, PyTorch)\n- Data analysis techniques such as statistical analysis and multivariate analysis\n- Self-localization and behavior planning technologies\n- Autonomous driving and advanced driver-assistance systems (ADAS) development\nIdeal Candidate Profile\nWe are looking for individuals who:'),
#  Document(metadata={'producer': 'Microsoft: Print To PDF', 'creator': 'PyPDF', 'creationdate': '2025-09-19T19:16:30+09:00', 'author': 'AtoJ-Ruchira', 'moddate': '2025-09-19T19:16:30+09:00', 'title': 'IITçŽ»é„²çﬂ¨Job Description(2025-2026)0903æ‘’å⁄º.xlsx', 'source': '..\\data\\pdf\\DNN Developer.pdf', 'total_pages': 2, 'page': 0, 'page_label': '1', 'source file': 'DNN Developer.pdf', 'file_type': 'pdf'}, page_content='- Self-localization and behavior planning technologies\n- Autonomous driving and advanced driver-assistance systems (ADAS) development\nIdeal Candidate Profile\nWe are looking for individuals who:\n- Aspire to create world-first technologies and contribute to society\n- Are passionate about eliminating traffic accidents\n- Wish to deliver new value to customers through mobility\n- Are eager to take on new challenges\n- Possess the energy to pursue ambitious goals to completion\n- Have the ambition to succeed on a global stage\n- Proactively express their ideas and engage others to find the best solutions to challenges\n- Communicate positively and effectively with diverse stakeholders\nJob Description\nSkills'),
#  Document(metadata={'producer': 'Microsoft: Print To PDF', 'creator': 'PyPDF', 'creationdate': '2025-09-19T19:16:30+09:00', 'author': 'AtoJ-Ruchira', 'moddate': '2025-09-19T19:16:30+09:00', 'title': 'IITçŽ»é„²çﬂ¨Job Description(2025-2026)0903æ‘’å⁄º.xlsx', 'source': '..\\data\\pdf\\DNN Developer.pdf', 'total_pages': 2, 'page': 1, 'page_label': '2', 'source file': 'DNN Developer.pdf', 'file_type': 'pdf'}, page_content='UNDERGRAD\nCTC (Cost to \nCompany) 9,045,000 JPY\nCTC (breakdown)\n・Basic salary: 6,553,000 JPY \n・Allowance(Meal, Commuting, etc): 460,000 JPY\n・House Rent: 1,032,000 JPY *Guarantee fee will be deducted from salary\u3000 \n・JPN language lesson:  1,000,000 JPY\nTake Home (In Hand) 5,088,000 JPY *After tax\nGross Taxable \nIncome 6,553,000 -9,097,000JPY  *depend on Bonus\nMonthly Fixed Pay546,000 JPY （424,000 JPY *After tax）\nBonus\nAfter every 6 months of evaluation (CTC calculations are before tax):\n1. Output meets the assignments: no incentive (CTC: JPY 9,045,000)\n2. Outstanding outputs: additional bonus(*after tax) of JPY 636,000 (CTC: JPY 9,045,000+819,000) \n3. Supreme outputs: additional bonus(*after tax) of JPY 1,272,000 (CTC: JPY 9,045,000+1,638,000) \nSo maximum CTC a candidate can get after 1 year depending upon his performance is JPY 9,045,000+ 1,638,000+ 1,638,000 = 12,321,000JPY'),
#  Document(metadata={'producer': 'Microsoft: Print To PDF', 'creator': 'PyPDF', 'creationdate': '2025-09-19T19:16:30+09:00', 'author': 'AtoJ-Ruchira', 'moddate': '2025-09-19T19:16:30+09:00', 'title': 'IITçŽ»é„²çﬂ¨Job Description(2025-2026)0903æ‘’å⁄º.xlsx', 'source': '..\\data\\pdf\\DNN Developer.pdf', 'total_pages': 2, 'page': 1, 'page_label': '2', 'source file': 'DNN Developer.pdf', 'file_type': 'pdf'}, page_content='So maximum CTC a candidate can get after 1 year depending upon his performance is JPY 9,045,000+ 1,638,000+ 1,638,000 = 12,321,000JPY \nAllowances Commuting allowance,Meal allowance,Allowance Upon Joining(\\150,000, Flight Tickets, Moving Expense, Cost for initial VISA)\nNo overtime allowance\nHolidays Annual Paid Leaves:\u300020 days annually\nBenefits\nEmployment insurance\nWorkers’ Accident insurance           *Social insurance fee is deducted from salary.\nHealth insurance\nPension Insurance\nOfficial Working \nHours Base 8 hours / day\nPOSTGRAD\nCTC (Cost to \nCompany) 9,045,000 JPY\nCTC (breakdown)\n・Basic salary: 6,553,000 JPY \n・Allowance(Meal, Commuting, etc): 460,000 JPY\n・House Rent: 1,032,000 JPY *Guarantee fee will be deducted from salary\u3000 \n・JPN language lesson:  1,000,000 JPY\nTake Home (In Hand) 5,088,000 JPY *After tax\nGross Taxable \nIncome 6,553,000 -9,097,000JPY  *depend on Bonus\nMonthly Fixed Pay546,000 JPY （424,000 JPY *After tax）\nBonus'),
#  Document(metadata={'producer': 'Microsoft: Print To PDF', 'creator': 'PyPDF', 'creationdate': '2025-09-19T19:16:30+09:00', 'author': 'AtoJ-Ruchira', 'moddate': '2025-09-19T19:16:30+09:00', 'title': 'IITçŽ»é„²çﬂ¨Job Description(2025-2026)0903æ‘’å⁄º.xlsx', 'source': '..\\data\\pdf\\DNN Developer.pdf', 'total_pages': 2, 'page': 1, 'page_label': '2', 'source file': 'DNN Developer.pdf', 'file_type': 'pdf'}, page_content='Take Home (In Hand) 5,088,000 JPY *After tax\nGross Taxable \nIncome 6,553,000 -9,097,000JPY  *depend on Bonus\nMonthly Fixed Pay546,000 JPY （424,000 JPY *After tax）\nBonus\nAfter every 6 months of evaluation (CTC calculations are before tax):\n1. Output meets the assignments: no incentive (CTC: JPY 9,045,000)\n2. Outstanding outputs: additional bonus(*after tax) of JPY 636,000 (CTC: JPY 9,045,000+819,000) \n3. Supreme outputs: additional bonus(*after tax) of JPY 1,272,000 (CTC: JPY 9,045,000+1,638,000) \nSo maximum CTC a candidate can get after 1 year depending upon his performance is JPY 9,045,000+ 1,638,000+ 1,638,000 = 12,321,000JPY \nAllowances Commuting allowance,Meal allowance,Allowance Upon Joining(\\150,000, Flight Tickets, Moving Expense, Cost for initial VISA)\nNo overtime allowance\nHolidays Annual Paid Leaves:\u300020 days annually\nBenefits\nEmployment insurance\nWorkers’ Accident insurance           *Social insurance fee is deducted from salary.\nHealth insurance\nPension Insurance'),
#  Document(metadata={'producer': 'Microsoft: Print To PDF', 'creator': 'PyPDF', 'creationdate': '2025-09-19T19:16:30+09:00', 'author': 'AtoJ-Ruchira', 'moddate': '2025-09-19T19:16:30+09:00', 'title': 'IITçŽ»é„²çﬂ¨Job Description(2025-2026)0903æ‘’å⁄º.xlsx', 'source': '..\\data\\pdf\\DNN Developer.pdf', 'total_pages': 2, 'page': 1, 'page_label': '2', 'source file': 'DNN Developer.pdf', 'file_type': 'pdf'}, page_content='Holidays Annual Paid Leaves:\u300020 days annually\nBenefits\nEmployment insurance\nWorkers’ Accident insurance           *Social insurance fee is deducted from salary.\nHealth insurance\nPension Insurance\nOfficial Working \nHours Base 8 hours / day')]

# %% [markdown]
# #### 3. Embedding and VectorStore DB

# %%
import numpy as np
from sentence_transformers import SentenceTransformer
import chromadb
from chromadb.config import Settings
import uuid
from typing import List, Dict, Any, Tuple
from sklearn.metrics.pairwise import cosine_similarity

# %%
class EmbeddingManager:
    """Handles document embedding generation using SentenceTransformer"""

    def __init__(self, model_name: str = "all-MiniLM-L6-v2"):
        """
        Initialize the embedding manager

        Args:
            model_name: HuggingFace model name for sentence embeddings
        """
        self.model_name = model_name
        self.model = None
        self._load_model()
    
    def _load_model(self):
        """Load the SentenceTransformer model"""
        try:
            print(f"Loading embedding model: {self.model_name}")
            self.model = SentenceTransformer(self.model_name)
            print(f"Model loader successfully. Embedding dimension: {self.model.get_sentence_embedding_dimension()}")
        except Exception as e:
            print(f"Error loading model {self.model_name}: {e}")
            raise
    
    def generate_embeddings(self, texts: List[str]) -> np.ndarray:
        """
        Generate embeddings for a list of texts
        
        Args:
            texts: List of text strings to embed
            
        Returns:
            numpy array of embeddings with shape (len(texts), embedding_dim)
        """
        if not self.model:
            raise ValueError("Model not loaded")
        
        print(f"Generating embeddings for {len(texts)} texts....")
        embeddings = self.model.encode(texts, show_progress_bar = True)
        print(f"Generated embeddings with shape: {embeddings.shape}")
        return embeddings
    
## Initialize the embedding manager
embedding_manager = EmbeddingManager()
embedding_manager
# Out:
# Loading embedding model: all-MiniLM-L6-v2
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# Model loader successfully. Embedding dimension: 384

# %% [markdown]
# #### 4. Vector Store

# %%
class VectorStore:
    """Manages document embeddings in a ChromaDB vectore store"""

    def __init__(self, collection_name: str = "pdf_documents", persist_directory: str = "../data/vectore_store"):
        """
        Initialize the vectore store

        Args:
            collection_name: Name of the ChromaDB collection
            persist_directory: Directory to persist the vectore store
        """
        self.collection_name = collection_name
        self.persist_directory = persist_directory
        self.client = None
        self.collection = None
        self._initialize_store()

    def _initialize_store(self):
        """Initialize ChromaDB client and collection"""
        try:
            # Create persistent ChromaDB client
            os.makedirs(self.persist_directory, exist_ok=True)
            self.client = chromadb.PersistentClient(path = self.persist_directory)

            # Get or create collection
            self.collection = self.client.get_or_create_collection(
                name = self.collection_name,
                metadata = {"description": "PDF document embeddings for RAG"}
            )
            print(f"Vector store initialized Collection: {self.collection_name}")
            print(f"Existing documents in collection: {self.collection.count()}")
        
        except Exception as e:
            print(f"Error initializing vector store: {e}")
            raise

    def add_documents(self, documents: List[Any], embeddings: np.ndarray):
        """
        Add documents and their embeddings to the vector store

        Args:
            documents: List of LangChain documents
            embeddings: Corresponding embeddings for the documents
        """
        if len(documents) != len(embeddings):
            raise ValueError("Number of documents must match number of embeddings")
        
        print(f"Adding {len(documents)} documents to vector store")

        # Prepare data for ChromaDB
        ids = []
        metadatas = []
        documents_text = []
        embeddings_list = []

        for i, (doc, embedding) in enumerate(zip(documents, embeddings)):
            # Generate unique ID
            doc_id = f"doc_{uuid.uuid4().hex[:8]}_{i}"
            ids.append(doc_id)

            # Prepare metadata
            metadata = dict(doc.metadata)
            metadata['doc_index'] = i
            metadata['content_length'] = len(doc.page_content)
            metadatas.append(metadata)

            # Document content
            documents_text.append(doc.page_content)

            # Embedding
            embeddings_list.append(embedding.tolist())
        
        # Add to collection
        try:
            self.collection.add(
                ids = ids,
                embeddings = embeddings_list,
                metadatas = metadatas,
                documents = documents_text
            )
            print(f"Successfully added {len(documents)} documents to vector store")
            print(f"Total documents in collection: {self.collection.count()}")
        except Exception as e:
            print(f"Error adding documents to vector store: {e}")
            raise

vectorstore = VectorStore()
vectorstore
# Out:
# Vector store initialized Collection: pdf_documents
# Existing documents in collection: 0

# %%
### convert the text to embeddings
texts = [doc.page_content for doc in chunks]

### Generate the embeddings
embeddings = embedding_manager.generate_embeddings(texts)

### Store in vector db
vectorstore.add_documents(chunks, embeddings)
# Out:
# Generating embeddings for 49 texts....
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches: 100%|██████████| 2/2 [00:01<00:00,  1.45it/s]
# Generated embeddings with shape: (49, 384)
# Adding 49 documents to vector store
# Successfully added 49 documents to vector store
# Total documents in collection: 49

# %% [markdown]
# #### 5. RAG retreiver

# %%
class RAGRetriever:
    """Handles query-based retrieval from the vector store"""
    def __init__(self, vector_store: VectorStore, embedding_manager: EmbeddingManager):
        """
        Initialize the retriever

        Args:
            vector_store: Vector store containing document embeddings
            embedding_manager: Manager for generating query embeddings
        """
        self.vectore_store = vector_store
        self.embedding_manager = embedding_manager

    def retrieve(self, query: str, top_k: int=5, score_threshold: float = 0.0) -> List[Dict[str, Any]]:
        """
        Retrieve relevant documents for a query

        Args:
            query: The search query
            top_k: Number of top results to return
            score_threshold: Minimum similarity score threshold

        Returns: 
            List of dictionaries containing retrieved documents and metadata
        """
        print(f"Retrieving documents for query: '{query}'")
        print(f"Top K: {top_k}, Score threshold: {score_threshold}")

        # Generate query embedding
        query_embedding = self.embedding_manager.generate_embeddings([query])[0]

        # Search in vector store
        try:
            results = self.vectore_store.collection.query(
                query_embeddings=[query_embedding.tolist()],
                n_results=top_k
            )

            # Process results
            retrieved_docs = []

            if results['documents'] and results['documents'][0]:
                documents = results['documents'][0]
                metadatas = results['metadatas'][0]
                distances = results['distances'][0]
                ids = results['ids'][0]

                for i, (doc_id, document, metadata, distance) in enumerate(zip(ids, documents, metadatas, distances)):
                    # Convert distance to similarity score (ChromaDB uses cosine distance)
                    similarity_score = 1 - distance

                    if similarity_score >= score_threshold:
                        retrieved_docs.append({
                            'id': doc_id,
                            'content':document,
                            'metadata': metadata,
                            'similarity_score': similarity_score,
                            'distance': distance,
                            'rank': i+1
                        })
                    print(f"Retrieved {len(retrieved_docs)} documents (after filtering)")
                else:
                    print("No documents found")
                
                return retrieved_docs
            
        except Exception as e:
            print(f"Error during retrieval: {e}")
            return []

rag_retriever = RAGRetriever(vectorstore, embedding_manager)

# %%
rag_retriever

# %%
rag_retriever.retrieve("what does honda want?")
# Out:
# Retrieving documents for query: 'what does honda want?'
# Top K: 5, Score threshold: 0.0
# Generating embeddings for 1 texts....
# Batches: 100%|██████████| 1/1 [00:00<00:00, 92.88it/s]
# Generated embeddings with shape: (1, 384)
# Retrieved 1 documents (after filtering)
# Retrieved 2 documents (after filtering)
# Retrieved 3 documents (after filtering)
# Retrieved 4 documents (after filtering)
# Retrieved 5 documents (after filtering)
# No documents found
# [{'id': 'doc_870a1404_1',
#   'content': 'We believe that having dreams and staying passionate about making them a reality is the reason Honda exists. "It\'s not about what happens; it\'s about what you do." You are the ones who will shape \nthe future of the world. As you move forward in life, we hope you will be the main character in the moments when the world changes.\nIf you have a desire to achieve something, to create something, or to make your dreams come true, why not realize those aspirations at Honda?\n〈Software Defined Vehicle Business Development Unit, Digital Engine Development Division〉\nAt Honda, The Power of Dreams inspires us to create intelligent, connected products that enhance mobility and bring joy to people’s lives. Our goal is to deliver affordable, AI-powered solutions that \nmake customers smile—by combining cutting-edge technology, ethical transparency, and collaborative innovation. The automotive industry is undergoing a profound transformation. Vehicles are',
#   'metadata': {'doc_index': 1,
#    'creationdate': '2025-09-19T19:17:00+09:00',
#    'moddate': '2025-09-19T19:17:00+09:00',
#    'total_pages': 2,
#    'source file': 'AI researcher.pdf',
#    'producer': 'Microsoft: Print To PDF',
#    'author': 'AtoJ-Ruchira',
#    'source': '..\\data\\pdf\\AI researcher.pdf',
#    'file_type': 'pdf',
#    'page': 0,
#    'title': 'IITçŽ»é„²çﬂ¨Job Description(2025-2026)0903æ‘’å⁄º.xlsx',
#    'content_length': 950,
#    'creator': 'PyPDF',
#    'page_label': '1'},
#   'similarity_score': 0.22218084335327148,
#   'distance': 0.7778191566467285,
#   'rank': 1},
#  {'id': 'doc_864fecae_0',
#   'content': 'Honda Motor Co., \nLtd. AI Research Engineer\nHonda is a total mobility company dedicated to delivering the "joy of free movement." We innovate in various fields, including motorcycles, automobiles, power products, aircraft and aircraft \nengines, and robotics. Honda operates in markets across about 200 countries worldwide, continuously creating next-generation mobility solutions and products that improve people’s lives by \ncombining our technology and expertise.\nAt Honda, everyone, regardless of nationality, gender, educational background, or experience, can freely express their ideas. Since our founding, we have maintained the ambition of asking, "What \ncan we do for the world and for people?"\nWe believe that having dreams and staying passionate about making them a reality is the reason Honda exists. "It\'s not about what happens; it\'s about what you do." You are the ones who will shape',
#   'metadata': {'page': 0,
#    'creator': 'PyPDF',
#    'source': '..\\data\\pdf\\AI researcher.pdf',
#    'content_length': 897,
#    'file_type': 'pdf',
#    'moddate': '2025-09-19T19:17:00+09:00',
#    'total_pages': 2,
#    'author': 'AtoJ-Ruchira',
#    'doc_index': 0,
#    'page_label': '1',
#    'producer': 'Microsoft: Print To PDF',
#    'source file': 'AI researcher.pdf',
#    'title': 'IITçŽ»é„²çﬂ¨Job Description(2025-2026)0903æ‘’å⁄º.xlsx',
#    'creationdate': '2025-09-19T19:17:00+09:00'},
#   'similarity_score': 0.20025360584259033,
#   'distance': 0.7997463941574097,
#   'rank': 2},
#  {'id': 'doc_a8fcb546_26',
#   'content': 'Honda Motor Co., \nLtd. Data Engineer\nHonda is a total mobility company dedicated to delivering the "joy of free movement." We innovate in various fields, including motorcycles, automobiles, power products, aircraft \nand aircraft engines, and robotics. Honda operates in markets across about 200 countries worldwide, continuously creating next-generation mobility solutions and products that \nimprove people’s lives by combining our technology and expertise.\nAt Honda, everyone, regardless of nationality, gender, educational background, or experience, can freely express their ideas. Since our founding, we have maintained the ambition of \nasking, "What can we do for the world and for people?"\nWe believe that having dreams and staying passionate about making them a reality is the reason Honda exists. "It\'s not about what happens; it\'s about what you do." You are the',
#   'metadata': {'page_label': '1',
#    'doc_index': 26,
#    'source': '..\\data\\pdf\\Data Engineer.pdf',
#    'content_length': 870,
#    'file_type': 'pdf',
#    'creator': 'PyPDF',
#    'producer': 'Microsoft: Print To PDF',
#    'title': 'IITçŽ»é„²çﬂ¨Job Description(2025-2026)0903æ‘’å⁄º.xlsx',
#    'source file': 'Data Engineer.pdf',
#    'author': 'AtoJ-Ruchira',
#    'total_pages': 2,
#    'moddate': '2025-09-19T19:16:02+09:00',
#    'page': 0,
#    'creationdate': '2025-09-19T19:16:02+09:00'},
#   'similarity_score': 0.18916338682174683,
#   'distance': 0.8108366131782532,
#   'rank': 3},
#  {'id': 'doc_5b216024_38',
#   'content': 'Honda Motor Co., \nLtd. Deep Neural Network (DNN) Development Engineer\nHonda is a total mobility company dedicated to delivering the "joy of free movement." We innovate in various fields, including motorcycles, automobiles, power products, aircraft \nand aircraft engines, and robotics. Honda operates in markets across about 200 countries worldwide, continuously creating next-generation mobility solutions and products that \nimprove people’s lives by combining our technology and expertise.\nAt Honda, everyone, regardless of nationality, gender, educational background, or experience, can freely express their ideas. Since our founding, we have maintained the ambition of \nasking, "What can we do for the world and for people?"\nWe believe that having dreams and staying passionate about making them a reality is the reason Honda exists. "It\'s not about what happens; it\'s about what you do." You are the',
#   'metadata': {'moddate': '2025-09-19T19:16:30+09:00',
#    'doc_index': 38,
#    'source': '..\\data\\pdf\\DNN Developer.pdf',
#    'author': 'AtoJ-Ruchira',
#    'producer': 'Microsoft: Print To PDF',
#    'total_pages': 2,
#    'creationdate': '2025-09-19T19:16:30+09:00',
#    'file_type': 'pdf',
#    'page': 0,
#    'source file': 'DNN Developer.pdf',
#    'page_label': '1',
#    'content_length': 903,
#    'title': 'IITçŽ»é„²çﬂ¨Job Description(2025-2026)0903æ‘’å⁄º.xlsx',
#    'creator': 'PyPDF'},
#   'similarity_score': 0.1719825267791748,
#   'distance': 0.8280174732208252,
#   'rank': 4},
#  {'id': 'doc_d652a209_27',
#   'content': 'We believe that having dreams and staying passionate about making them a reality is the reason Honda exists. "It\'s not about what happens; it\'s about what you do." You are the \nones who will shape the future of the world. As you move forward in life, we hope you will be the main character in the moments when the world changes.\nIf you have a desire to achieve something, to create something, or to make your dreams come true, why not realize those aspirations at Honda?\n〈Software Defined Mobility Development Supervisory Unit, Advanced Safety and Intelligent Solution Development Division〉\nOur mission is to develop world-leading safety features and autonomous driving systems, and to deliver the safest vehicles in the world. Honda\'s AD/ADAS Data Platform Group \nprovides an ecosystem for AD/ADAS system development to analyze and test safety and functionality through simulations, insight and analysis of sensing data from test vehicles. The',
#   'metadata': {'moddate': '2025-09-19T19:16:02+09:00',
#    'content_length': 944,
#    'total_pages': 2,
#    'creationdate': '2025-09-19T19:16:02+09:00',
#    'page_label': '1',
#    'creator': 'PyPDF',
#    'page': 0,
#    'author': 'AtoJ-Ruchira',
#    'producer': 'Microsoft: Print To PDF',
#    'title': 'IITçŽ»é„²çﬂ¨Job Description(2025-2026)0903æ‘’å⁄º.xlsx',
#    'doc_index': 27,
#    'file_type': 'pdf',
#    'source file': 'Data Engineer.pdf',
#    'source': '..\\data\\pdf\\Data Engineer.pdf'},
#   'similarity_score': 0.13127726316452026,
#   'distance': 0.8687227368354797,
#   'rank': 5}]

# %% [markdown]
# **We can now get any context ranked for a query as you can see above**

# %% [markdown]
# #### 6. Integrating VectorDB context pipeline with LLM output

# %%
### Simple RAG pipeline with Groq LLM
from langchain_groq import ChatGroq
import os
from dotenv import load_dotenv
load_dotenv()

### Initialize the Groq LLM (set your GROQ_API_KEY in environment)
groq_api_key = os.getenv("GROQ_API_KEY")

llm = ChatGroq(groq_api_key = groq_api_key, model_name ="llama-3.1-8b-instant", temperature = 0.1, max_tokens = 1024)

## 2. Simple RAG function: retrieve context +  generate response

def rag_simple(query, retriever, llm, top_k = 3):
    ## retrieve the context 
    results = retriever.retrieve(query, top_k = top_k)
    context = "\n\n".join([doc['content'] for doc in results]) if results else ""
    if not context:
        return "No relevant context found to answer the question."
    ## generate the answer using groq LLM
    prompt = f"""Use the following context to answer the question concisely.
            context:
            {context}

            Question: {query}

            Answer:"""
    
    response = llm.invoke([prompt.format(context = context, query = query)])
    return response.content

# %%
answer = rag_simple("AI research engineer role", rag_retriever, llm)
print(answer)
# Out:
# Retrieving documents for query: 'AI research engineer role'
# Top K: 3, Score threshold: 0.0
# Generating embeddings for 1 texts....
# Batches: 100%|██████████| 1/1 [00:00<00:00, 124.13it/s]
# Generated embeddings with shape: (1, 384)
# Retrieved 1 documents (after filtering)
# Retrieved 2 documents (after filtering)
# Retrieved 3 documents (after filtering)
# No documents found
# AI Research Engineer Role:
#
# This role involves implementing advanced analytics and automation functionalities, including ML and Gen-AI techniques for intelligent data analysis, and collaborating with stakeholders to drive innovation in the field of mobility.

# %% [markdown]
# #### 7. Enhanced RAG pipeline features

# %%
def rag_advanced(query, retriever, llm, top_k=5, min_score=0.2, return_context=False):
    """
    RAG pipeline with extra features:
    - Returns answer, sources, confidence, score, and optionally full context.
    """
    results = retriever.retrieve(query, top_k = top_k, score_threshold = min_score)

    if not results:
        return {'answer': 'No relevant context found.', 'sources': [], 'confidence': 0.0, 'context': ''}
    
    # Prepare context and sources
    context = "\n\n".join([doc['content'] for doc in results])
    sources = [{
        'source': doc['metadata'].get('source_file', doc['metadata'].get('source', 'unknown')),
        'page': doc['metadata'].get('page', 'unknown'),
        'score': doc['similarity_score'],
        'preview': doc['content'][:120] + '...'
    } for doc in results]
    confidence = max(doc['similarity_score'] for doc in results)

    # Generate answer
    prompt = f"""Use the following context to answer the question concisely.\nContext:\n{context}:\n\nQuestion: {query}\n\nAnswer:{answer}"""
    response = llm.invoke([prompt.format(context = context, query = query)])

    output = {
        'answer': response.content,
        'sources': sources,
        'confidence': confidence
    }
    if return_context:
        output['context'] = context
    return output

# Example output
result = rag_advanced("How to prepare for AI engineer role?", rag_retriever, llm, top_k = 10, min_score = 0.0, return_context = True)
print("Answer:", result['answer'])
print("Source:", result['sources'])
print("Confidence:", result['confidence'])
print("Context Preview:", result['context'][:300])
# Out:
# Retrieving documents for query: 'How to prepare for AI engineer role?'
# Top K: 10, Score threshold: 0.0
# Generating embeddings for 1 texts....
# Batches: 100%|██████████| 1/1 [00:00<00:00, 105.77it/s]
# Generated embeddings with shape: (1, 384)
# Retrieved 1 documents (after filtering)
# Retrieved 2 documents (after filtering)
# Retrieved 3 documents (after filtering)
# Retrieved 4 documents (after filtering)
# Retrieved 4 documents (after filtering)
# Retrieved 4 documents (after filtering)
# Retrieved 4 documents (after filtering)
# Retrieved 4 documents (after filtering)
# Retrieved 4 documents (after filtering)
# Retrieved 4 documents (after filtering)
# No documents found
# Answer: To prepare for an AI Engineer role, focus on the following:
#
# 1. **Education**: Pursue a Master's or Dual Degree in Data Science and AI, Computer Science, or Information Science with a focus on AI/ML, GenAI, and Analytics.
# 2. **Technical Skills**:
# 	* Develop expertise in image processing, image recognition technology development, recognition technology using RADAR or LiDAR, Generative AI, and large language models (LLMs).
# 	* Familiarize yourself with foundational AI technologies like machine learning and deep learning, and AI-related tools such as Caffe, Chainer, TensorFlow, and PyTorch.
# 	* Learn data analysis techniques like statistical analysis and multivariate analysis.
# 3. **Programming Languages**: Master R, Python, and SQL, and familiarize yourself with data analysis/AI libraries like numpy, scipy, scikit-learn, Jupyter Notebook, and PyTorch.
# 4. **Simulation Tools**: Learn Matlab/Simulink, CarMaker, and Carla for simulation and modeling.
# 5. **Soft Skills**:
# 	* Develop strong critical thinking and problem-solving abilities.
# 	* Improve communication skills to effectively convey technical content to various audiences.
# 	* Cultivate an innate curiosity and bias to action, with the ability to identify, define, and execute project plans.
# 	* Enhance your ability to thrive in an environment of autonomy amidst ambiguity.
# 6. **Stay Up-to-Date**: Continuously update your knowledge and skills to keep pace with the rapidly evolving field of AI and machine learning.
# 7. **Gain Practical Experience**: Participate in projects, internships, or research collaborations to apply your knowledge and skills in real-world scenarios.
# 8. **Network**: Build relationships with professionals in the field and stay connected with academic and industry communities to stay informed about the latest developments and opportunities.
# Source: [{'source': '..\\data\\pdf\\apple_jd.pdf', 'page': 0, 'score': 0.1757088303565979, 'preview': 'teams. Strong critical thinking and problem solving ability\n• Sound communication skills - adept at messaging domain and...'}, {'source': '..\\data\\pdf\\DNN Developer.pdf', 'page': 0, 'score': 0.13342034816741943, 'preview': '*Depending on your expertise, aptitude, and company needs, you may be reassigned to other duties as defined by the compa...'}, {'source': '..\\data\\pdf\\Applied Data Scientist.pdf', 'page': 0, 'score': 0.09147077798843384, 'preview': '- Implement advanced analytics and automation funcationalities, inclduing ML and Gen-AI techniques for intelligent data ...'}, {'source': '..\\data\\pdf\\DNN Developer.pdf', 'page': 0, 'score': 0.027501285076141357, 'preview': '- Behavior planning algorithms and machine learning models based on traffic conditions\n- Edge device deployment of machi...'}]
# Confidence: 0.1757088303565979
# Context Preview: teams. Strong critical thinking and problem solving ability
# • Sound communication skills - adept at messaging domain and technical content, at a
# level appropriate for the audience.
# • Experienced at understanding key performance levers and metrics to highlight
# operational issues and drive improveme
